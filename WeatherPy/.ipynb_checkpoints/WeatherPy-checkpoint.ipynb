# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?" + "appid=" + weather_api_key + "&q="
units = "&units=imperial"

print("Beginning Data Retrieval")
print("------------------------------")

city_name = []
latitude = []
longitude = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
weather_date = []

for city in cities:
    try:
        response = requests.get(url + city + units).json()
        city_name.append(response['name'])
        city_id = response['id']
        city = response['name']
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        weather_date.append(response['dt'])
        print(f"Processing Record {city_id} | {city}")
    
    except:
        print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 556268 | Ostrovnoy
# Processing Record 3652764 | Puerto Ayora
# Processing Record 6111862 | Port Hardy
# Processing Record 1695736 | Panalingaan
# Processing Record 964432 | Port Alfred
# Processing Record 3366880 | Hermanus
# Processing Record 3430863 | Mar del Plata
# Processing Record 155285 | Mahanje
# Processing Record 2126123 | Chokurdakh
# Processing Record 3460940 | Itacaré
# Processing Record 6171633 | Ucluelet
# Processing Record 1648759 | Bima
# Processing Record 2012956 | Yerbogachën
# Processing Record 4030556 | Rikitea
# Processing Record 6201424 | Mataura
# Processing Record 1006984 | East London
# Processing Record 2396518 | Port-Gentil
# Processing Record 2112802 | Hasaki
# Processing Record 5380420 | Pacifica
# City not found. Skipping...
# Processing Record 2063036 | Port Lincoln
# City not found. Skipping...
# Processing Record 519611 | Novaya Mayna
# Processing Record 4031637 | Lavrentiya
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3369157 | Cape Town
# Processing Record 3948613 | Acarí
# Processing Record 5855927 | Hilo
# Processing Record 2618795 | Klaksvík
# Processing Record 1265053 | Lar
# Processing Record 2015306 | Tiksi
# Processing Record 2075265 | Busselton
# Processing Record 3833367 | Ushuaia
# Processing Record 3382160 | Cayenne
# Processing Record 3874787 | Punta Arenas
# City not found. Skipping...
# Processing Record 3372707 | Ribeira Grande
# Processing Record 2110227 | Butaritari
# Processing Record 5380437 | Pacific Grove
# Processing Record 6089245 | Norman Wells
# Processing Record 5122534 | Jamestown
# Processing Record 558209 | Nagornskiy
# Processing Record 2610343 | Vestmanna
# Processing Record 2191562 | Dunedin
# Processing Record 4036284 | Alofi
# City not found. Skipping...
# Processing Record 3372964 | Lagoa
# Processing Record 6185377 | Yellowknife
# City not found. Skipping...
# Processing Record 1254046 | Tura
# Processing Record 1637001 | Biak
# Processing Record 2074865 | Carnarvon
# Processing Record 2120591 | Tilichiki
# Processing Record 5106841 | Albany
# Processing Record 2128382 | Rumoi
# Processing Record 1259385 | Port Blair
# City not found. Skipping...
# Processing Record 5367788 | Lompoc
# Processing Record 905846 | Mpika
# Processing Record 1631637 | Pemangkat
# Processing Record 2129376 | Kushiro
# City not found. Skipping...
# Processing Record 3831208 | Qaanaaq
# Processing Record 1626703 | Soe
# Processing Record 780687 | Berlevåg
# Processing Record 4032243 | Vaini
# Processing Record 1487332 | Verkhnyaya Inta
# Processing Record 5913695 | Cambridge
# Processing Record 3471451 | Arraial do Cabo
# Processing Record 2071860 | Esperance
# Processing Record 934322 | Mahébourg
# Processing Record 2163355 | Hobart
# Processing Record 5880054 | Barrow
# Processing Record 3374210 | São Filipe
# Processing Record 5546220 | Saint George
# Processing Record 2017155 | Saskylakh
# Processing Record 5557293 | Sitka
# Processing Record 1507390 | Dikson
# City not found. Skipping...
# Processing Record 5282297 | Bethel
# Processing Record 1015776 | Bredasdorp
# Processing Record 553766 | Kamenka
# Processing Record 3646487 | Carora
# Processing Record 5887916 | Athabasca
# City not found. Skipping...
# Processing Record 2729907 | Longyearbyen
# Processing Record 935214 | Saint-Pierre
# Processing Record 3932145 | Pisco
# Processing Record 2013639 | Verkhnevilyuysk
# Processing Record 3466704 | Castro
# Processing Record 2179103 | Whitianga
# Processing Record 4020109 | Atuona
# Processing Record 5954718 | Flin Flon
# Processing Record 5866583 | Saint Paul Harbor
# Processing Record 1106677 | Bambous Virieux
# Processing Record 1657818 | Champasak
# Processing Record 2027316 | Ayan
# Processing Record 6153766 | Spirit River
# Processing Record 2015217 | Tokur
# Processing Record 3174050 | Province of Mantua
# Processing Record 2399371 | Makokou
# Processing Record 6165406 | Thompson
# Processing Record 3897774 | Buin
# Processing Record 1735106 | George Town
# Processing Record 1791779 | Wanning
# Processing Record 1035025 | Nacala
# Processing Record 3418910 | Upernavik
# City not found. Skipping...
# Processing Record 2374583 | Bubaque
# Processing Record 5110365 | Broome
# City not found. Skipping...
# Processing Record 2092164 | Lorengau
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3893726 | Constitución
# Processing Record 6148373 | Sioux Lookout
# Processing Record 2264557 | Ponta do Sol
# Processing Record 2313002 | Matadi
# Processing Record 1717787 | Catuday
# Processing Record 3361934 | Saldanha
# Processing Record 1282256 | Hithadhoo
# Processing Record 2022572 | Khatanga
# Processing Record 933995 | Souillac
# Processing Record 352733 | Marsá Maţrūḩ
# City not found. Skipping...
# Processing Record 6167817 | Torbay
# Processing Record 5969025 | Haines Junction
# Processing Record 64013 | Bosaso
# Processing Record 2206939 | Bluff
# Processing Record 2664855 | Värnamo
# Processing Record 150689 | Poli
# Processing Record 2063042 | Port Hedland
# Processing Record 64814 | Bandarbeyla
# Processing Record 1734705 | Kuala Terengganu
# Processing Record 5391791 | San Clemente
# Processing Record 359783 | Assiut
# Processing Record 3448455 | São Miguel do Araguaia
# City not found. Skipping...
# Processing Record 286621 | Salalah
# Processing Record 474603 | Verkhnyaya Maksakovka
# City not found. Skipping...
# Processing Record 543508 | Kovdor
# Processing Record 2038067 | Chifeng
# Processing Record 2643044 | Margate
# Processing Record 3666881 | Toro
# Processing Record 124647 | Bardsīr
# Processing Record 935215 | Saint-Philippe
# Processing Record 4034551 | Faanui
# Processing Record 2255304 | Sémbé
# Processing Record 4447161 | Starkville
# Processing Record 2160517 | Launceston
# Processing Record 3464724 | Diamantino
# Processing Record 2122090 | Pevek
# Processing Record 4944903 | Nantucket
# Processing Record 1250161 | Batticaloa
# Processing Record 3372760 | Praia da Vitória
# Processing Record 4231997 | Avera
# Processing Record 3466165 | Cidreira
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 2208425 | Zuwārah
# Processing Record 3839307 | Rawson
# Processing Record 2063039 | Port Keats
# Processing Record 2070998 | Geraldton
# Processing Record 2079582 | Alyangula
# Processing Record 3352263 | Warmbad
# Processing Record 486626 | Sergiyevsk
# Processing Record 1244926 | Hambantota
# City not found. Skipping...
# Processing Record 2144764 | Wangaratta
# Processing Record 4174600 | Sweetwater
# Processing Record 1730622 | Anito
# Processing Record 2396853 | Omboué
# Processing Record 1521762 | Kurchum
# Processing Record 3421719 | Narsaq
# Processing Record 2065594 | Mount Isa
# Processing Record 5848280 | Kapaa
# Processing Record 107304 | Buraidah
# Processing Record 3883457 | Lebu
# Processing Record 2027276 | Babushkin
# City not found. Skipping...
# Processing Record 6145890 | Shelburne
# Processing Record 1710519 | Isabela
# Processing Record 3355672 | Lüderitz
# Processing Record 3421319 | Nuuk
# Processing Record 986717 | Kruisfontein
# Processing Record 2126199 | Cherskiy
# Processing Record 4004161 | Jalcocotán
# Processing Record 5924351 | Clyde River
# Processing Record 2109701 | Auki
# Processing Record 2208248 | Kaitangata
# Processing Record 2170577 | Cooma
# Processing Record 2063056 | Port Augusta
# Processing Record 4035715 | Avarua
# Processing Record 3469190 | Boquira
# Processing Record 108410 | Riyadh
# Processing Record 1511057 | Bakchar
# Processing Record 1235846 | Matara
# Processing Record 5847411 | Kahului
# Processing Record 5955084 | Foam Lake
# Processing Record 2450173 | Taoudenni
# Processing Record 5563839 | Fortuna
# Processing Record 1160571 | Khāsh
# Processing Record 1649150 | Bengkulu
# Processing Record 1264527 | Chennai
# Processing Record 2032614 | Baruun-Urt
# Processing Record 3628473 | San Cristobal
# Processing Record 1492566 | Severo-Yeniseyskiy
# Processing Record 4392354 | Jasper
# Processing Record 3620266 | Corn Island
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 161901 | Kaka
# Processing Record 5364271 | Laguna
# Processing Record 2649738 | Fairlie
# Processing Record 1489853 | Tazovsky
# Processing Record 210939 | Luebo
# Processing Record 4031574 | Provideniya
# Processing Record 3423146 | Ilulissat
# Processing Record 1257587 | Sālūr
# Processing Record 4787534 | Sterling
# Processing Record 1692685 | Puerto Princesa City
# City not found. Skipping...
# Processing Record 57000 | Hobyo
# Processing Record 1487260 | Verkhnyaya Sysert’
# City not found. Skipping...
# Processing Record 2094342 | Kavieng
# Processing Record 2037485 | Erenhot
# Processing Record 2447513 | Arlit
# Processing Record 546105 | Nikolskoye
# Processing Record 3445026 | Vila Velha
# Processing Record 2013279 | Vostok
# Processing Record 2144528 | Warrnambool
# Processing Record 523392 | Naryan-Mar
# Processing Record 2138555 | Poum
# Processing Record 2171099 | Codrington
# Processing Record 1788522 | Hancheng
# City not found. Skipping...
# Processing Record 1853174 | Sakaiminato
# Processing Record 2444219 | Gouré
# Processing Record 2454268 | Koutiala
# Processing Record 2025256 | Chumikan
# Processing Record 2270385 | Camacha
# Processing Record 1801615 | Maba
# Processing Record 1071296 | Antalaha
# Processing Record 341742 | Bonga
# Processing Record 510911 | Pervomayskiy
# Processing Record 2178753 | Kirakira
# Processing Record 2155415 | New Norfolk
# Processing Record 610864 | Khani
# Processing Record 2562247 | Marsaxlokk
# Processing Record 3372472 | Vila Franca do Campo
# Processing Record 2123814 | Leningradskiy
# City not found. Skipping...
# Processing Record 2126682 | Bilibino
# Processing Record 2422465 | Conakry
# Processing Record 4032369 | Pangai
# Processing Record 2982076 | Sablé-sur-Sarthe
# Processing Record 3463939 | Espinosa
# Processing Record 1525988 | Ayagoz
# Processing Record 1701054 | Marawi
# Processing Record 3129857 | Aranjuez
# Processing Record 2271968 | Aljezur
# Processing Record 2656258 | Barrhead
# Processing Record 6137462 | Saint-Augustin
# Processing Record 6620467 | St-Jean-Port-Joli
# Processing Record 2101169 | Aitape
# Processing Record 1650434 | Bambanglipuro
# Processing Record 2022129 | Kichera
# Processing Record 1821993 | Svay Rieng
# Processing Record 791516 | Resavica
# Processing Record 1215502 | Banda Aceh
# City not found. Skipping...
# Processing Record 6125862 | Roblin
# Processing Record 1735799 | Sri Aman
# Processing Record 2685750 | Östersund
# Processing Record 503772 | Puteyets
# Processing Record 1168700 | Ormara
# Processing Record 967106 | Oudtshoorn
# Processing Record 1501000 | Kyshtovka
# City not found. Skipping...
# Processing Record 2738381 | Lata
# Processing Record 5069297 | Grand Island
# Processing Record 6112862 | Preeceville
# Processing Record 2943049 | Brunsbüttel
# Processing Record 3860443 | Comodoro Rivadavia
# Processing Record 1651810 | Airai
# City not found. Skipping...
# Processing Record 2985020 | Conil
# City not found. Skipping...
# Processing Record 3393692 | Itarema
# Processing Record 257282 | Melivoia
# Processing Record 5911745 | Burns Lake
# Processing Record 5554428 | Ketchikan
# Processing Record 2137773 | Vao
# Processing Record 916246 | Kabompo
# Processing Record 2520645 | Cabra
# Processing Record 3526756 | Isla Mujeres
# Processing Record 336454 | Ginir
# Processing Record 3389822 | Salinópolis
# Processing Record 2732340 | Mata
# Processing Record 2091996 | Madang
# Processing Record 3985168 | San Patricio
# Processing Record 5264475 | New Richmond
# Processing Record 1797551 | Qinzhou
# Processing Record 3139597 | Sistranda
# Processing Record 2047258 | Novyy Urgal
# Processing Record 1524302 | Ereymentau
# Processing Record 2121385 | Severo-Kuril'sk
# Processing Record 3547867 | Manzanillo
# Processing Record 6690296 | Saint-Joseph
# Processing Record 1805757 | Jimo
# Processing Record 1529660 | Aksu
# Processing Record 2538474 | Rabat
# City not found. Skipping...
# Processing Record 110690 | Faya
# Processing Record 2122262 | Palana
# Processing Record 3573374 | The Valley
# Processing Record 3374235 | Sal Rei
# Processing Record 2640377 | Penzance
# Processing Record 2464701 | Tataouine
# Processing Record 1168749 | Nushki
# Processing Record 2180991 | Tolaga Bay
# Processing Record 1855342 | Nishihara
# Processing Record 5859699 | College
# Processing Record 5955902 | Fort Nelson
# Processing Record 3910343 | Mineros
# Processing Record 2281120 | Tabou
# City not found. Skipping...
# Processing Record 3377301 | Mabaruma
# Processing Record 1067565 | Beloha
# Processing Record 3446692 | Tatuí
# Processing Record 3380290 | Sinnamary
# Processing Record 1273463 | Darlawn
# Processing Record 2265447 | Olhão
# Processing Record 2173911 | Broken Hill
# Processing Record 2084246 | Wabag
# Processing Record 2177069 | Ballina
# Processing Record 86049 | Jalu
# City not found. Skipping...
# Processing Record 3163198 | Åmot
# Processing Record 114259 | Sīrjān
# Processing Record 1698289 | Pundaguitan
# Processing Record 3398856 | Grajaú
# City not found. Skipping...
# Processing Record 3493032 | San Pedro de Macorís
# Processing Record 932987 | Tsabong
# Processing Record 935616 | Le Port
# Processing Record 2122614 | Okha
# Processing Record 3662927 | Pauini
# Processing Record 1726449 | Basco
# Processing Record 178093 | Witu
# Processing Record 6170031 | Tuktoyaktuk
# Processing Record 3200651 | Glamoč
# City not found. Skipping...
# Processing Record 2033934 | Xiaoshi
# Processing Record 3897347 | Calama
# Processing Record 3996426 | Matamoros
# Processing Record 3445459 | Várzea da Palma
# Processing Record 2753718 | Gemeente Hoogeveen
# Processing Record 3887344 | Illapel
# Processing Record 1506499 | Glyadyanskoye
# City not found. Skipping...
# Processing Record 1214026 | Sabang
# Processing Record 1263752 | Māngrol
# Processing Record 2055868 | Yantal'
# City not found. Skipping...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data_df = pd.DataFrame({
    "City":city_name,
    "Lat":latitude,
    "Lon":longitude,
    "Max Temp":max_temp,
    "Humidity":humidity,
    "Cloudiness":cloudiness,
    "Wind Speed":wind_speed,
    "Country":country,
    "Date":weather_date     
})

weather_data_df.count()
# Out:
# City          565
# Lat           565
# Lon           565
# Max Temp      565
# Humidity      565
# Cloudiness    565
# Wind Speed    565
# Country       565
# Date          565
# dtype: int64

# %%
weather_data_df.head()
# Out:
#            City    Lat     Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Ostrovnoy  68.05   39.51     49.55        76          79        4.16
# 1  Puerto Ayora  -0.74  -90.35     75.20        69          75       18.34
# 2    Port Hardy  50.70 -127.42     55.40        87          75        5.82
# 3   Panalingaan   8.78  117.42     78.82        83          56        4.50
# 4   Port Alfred -33.59   26.89     61.14        39          47       33.06
#
#   Country        Date
# 0      RU  1594659264
# 1      EC  1594659237
# 2      CA  1594659249
# 3      PH  1594659704
# 4      ZA  1594659175

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_data_df.describe()
# Out:
#               Lat         Lon    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  565.000000  565.000000  565.000000  565.000000  565.000000  565.000000
# mean    19.973664   17.392549   70.787186   67.555752   50.900885    7.969239
# std     32.977451   90.045809   15.179642   21.796752   36.142313    5.383503
# min    -54.800000 -175.200000   32.000000    2.000000    0.000000    0.200000
# 25%     -7.840000  -63.600000   59.000000   55.000000   17.000000    3.980000
# 50%     24.050000   22.800000   73.000000   73.000000   54.000000    6.930000
# 75%     48.470000   98.250000   81.610000   84.000000   84.000000   10.690000
# max     78.220000  179.320000  109.170000  100.000000  100.000000   33.060000
#
#                Date
# count  5.650000e+02
# mean   1.594660e+09
# std    2.353686e+02
# min    1.594659e+09
# 25%    1.594659e+09
# 50%    1.594660e+09
# 75%    1.594660e+09
# max    1.594660e+09

# %%
# Make a new DataFrame to drop any cities with a humidity greather than 100
lower_humidity_df = weather_data_df.loc[weather_data_df["Humidity"] <= 100, :]

lower_humidity_df.to_csv("output_data/WeatherData.csv", index=False, header=True)

lower_humidity_df.head()
# Out:
#            City    Lat     Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Ostrovnoy  68.05   39.51     49.55        76          79        4.16
# 1  Puerto Ayora  -0.74  -90.35     75.20        69          75       18.34
# 2    Port Hardy  50.70 -127.42     55.40        87          75        5.82
# 3   Panalingaan   8.78  117.42     78.82        83          56        4.50
# 4   Port Alfred -33.59   26.89     61.14        39          47       33.06
#
#   Country        Date
# 0      RU  1594659264
# 1      EC  1594659237
# 2      CA  1594659249
# 3      PH  1594659704
# 4      ZA  1594659175

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
today_date = pd.to_datetime('today').strftime("%m/%d/%Y")

plt.scatter(lower_humidity_df["Lat"],lower_humidity_df["Max Temp"], edgecolor = 'black')
plt.grid(color="black", linewidth=1,alpha=0.20)
plt.title("City Latitude vs Max Temperature (" + today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.savefig("output_data/LatitudeVSMaxTemperature.png")
plt.show()

# %% [markdown]
# #### The graph is showing the correlation between latitude and maximum tempature. The closer to the equator (0 Latitude), the hotter the temperatures.

# %%
plt.scatter(lower_humidity_df["Lat"],lower_humidity_df["Humidity"], edgecolor = 'black')
plt.grid(color="black", linewidth=1,alpha=0.20)
plt.title("City Latitude vs Humidity (" + today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.savefig("output_data/LatitudeVSHumidity.png")
plt.show()

# %% [markdown]
# #### The graph is showing the correlation between latitude and humidity. There does not appear to be a correlation between latitude and humidity.

# %%
plt.scatter(lower_humidity_df["Lat"],lower_humidity_df["Cloudiness"], edgecolor = 'black')
plt.grid(color="black", linewidth=1,alpha=0.20)
plt.title("City Latitude vs Cloudiness (" + today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.savefig("output_data/LatitudeVSCloudiness.png")
plt.show()

# %% [markdown]
# #### The graph is showing the correlation between latitude and cloudiness. There does not appear to be a correlation between latitude and cloudiness.

# %%
plt.scatter(lower_humidity_df["Lat"],lower_humidity_df["Wind Speed"], edgecolor = 'black')
plt.grid(color="black", linewidth=1,alpha=0.20)
plt.title("City Latitude vs Wind Speed (" + today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig("output_data/LatitudeVSWindSpeed.png")
plt.show()

# %% [markdown]
# #### The graph is showing the correlation between latitude and wind speed. It appears no matter what latitude the wind speeds are lower with a few outliers.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def hemp_regression(x_values,y_values,y_axis_name,hemisphere):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(x_values.min(), y_values.min()),fontsize=15,color="red")
    plt.title(hemisphere + " - " + y_axis_name + " vs. Latitude Linear Regression")
    plt.xlabel("Latitude")
    plt.ylabel(y_axis_name)
    print(f"The r-squared is: {rvalue**2}")
    plt.savefig("output_data/Regression_"+ hemisphere + "_LatitudeVs" + y_axis_name + ".png")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere_df = lower_humidity_df.loc[lower_humidity_df["Lat"] >= 0, :]
northern_hemisphere_df.head()
# Out:
#            City    Lat     Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Ostrovnoy  68.05   39.51     49.55        76          79        4.16
# 2    Port Hardy  50.70 -127.42     55.40        87          75        5.82
# 3   Panalingaan   8.78  117.42     78.82        83          56        4.50
# 8    Chokurdakh  70.63  147.92     54.75        65          43        9.73
# 10     Ucluelet  48.93 -125.55     57.99       100          90        4.70
#
#    Country        Date
# 0       RU  1594659264
# 2       CA  1594659249
# 3       PH  1594659704
# 8       RU  1594659237
# 10      CA  1594659705

# %%
# Create Northern and Southern Hemisphere DataFrames
southern_hemisphere_df = lower_humidity_df.loc[lower_humidity_df["Lat"] < 0, :]
southern_hemisphere_df.head()
# Out:
#             City    Lat    Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 1   Puerto Ayora  -0.74 -90.35     75.20        69          75       18.34
# 4    Port Alfred -33.59  26.89     61.14        39          47       33.06
# 5       Hermanus -34.42  19.23     53.01        63          98        8.99
# 6  Mar del Plata -38.00 -57.56     46.40        55          40       19.46
# 7        Mahanje  -9.93  35.33     63.30        58          26        1.57
#
#   Country        Date
# 1      EC  1594659237
# 4      ZA  1594659175
# 5      ZA  1594659166
# 6      AR  1594659255
# 7      TZ  1594659705

# %%
hemp_regression(northern_hemisphere_df["Lat"],northern_hemisphere_df["Max Temp"],"Max Temp","Northern Hemisphere")
# Out:
# The r-squared is: 0.4861854398462884

# %%
hemp_regression(southern_hemisphere_df["Lat"],southern_hemisphere_df["Max Temp"],"Max Temp","Southern Hemisphere")
# Out:
# The r-squared is: 0.6413980404890077

# %% [markdown]
# #### In both hemispheres, there appears to be a direct correlation between latitude and temperature. As the latitude increases the temperature decreases and as the latitude decreases the temperature increases.

# %%
hemp_regression(northern_hemisphere_df["Lat"],northern_hemisphere_df["Humidity"],"Humidity","Northern Hemisphere")
# Out:
# The r-squared is: 0.0020511446783615882

# %%
hemp_regression(southern_hemisphere_df["Lat"],southern_hemisphere_df["Humidity"],"Humidity","Southern Hemisphere")
# Out:
# The r-squared is: 0.016234254858494775

# %% [markdown]
# #### There appears to be no correlation between latitude and humidity. The regression lines are pretty straight showing there is no way of determing humidity based on latitude and vice versa.

# %%
hemp_regression(northern_hemisphere_df["Lat"],northern_hemisphere_df["Cloudiness"],"Cloudiness","Northern Hemisphere")
# Out:
# The r-squared is: 0.0019132766687597128

# %%
hemp_regression(southern_hemisphere_df["Lat"],southern_hemisphere_df["Cloudiness"],"Cloudiness","Southern Hemisphere")
# Out:
# The r-squared is: 0.0038682110427816167

# %% [markdown]
# #### In the northern hemisphere, the regression line is almost flat which shows there is not much of a correlation between latitude and cloudiness. In the southern hemisphere, the line has a slight upward trend which denotes that as latitude decreases the cloudiness increases.

# %%
hemp_regression(northern_hemisphere_df["Lat"],northern_hemisphere_df["Wind Speed"],"Wind Speed","Northern Hemisphere")
# Out:
# The r-squared is: 0.0023271746534842186

# %%
hemp_regression(southern_hemisphere_df["Lat"],southern_hemisphere_df["Wind Speed"],"Wind Speed","Southern Hemisphere")
# Out:
# The r-squared is: 0.03906160512274336

# %% [markdown]
# #### In the northern hemisphere, the regression line is almost flat which shows there is not much of a correlation between latitude and wind speed. In the southern hemisphere, the line has a slight downward trend which denotes that as latitude increases the cloudiness decreases.

# %% [markdown]
# # Observable Trends

# %% [markdown]
# #### 1. There appears to be a correlation between latitude and max temperature. As the latitude gets closer to 0, the temperature is higher.
#
# #### 2. There does not appear to be as good of a correlation between latitude and the other parameters (cloudiness, humidity and wind speed.
#
# #### 3. When you look at the data between northern and southern hemisphere, there are slight correlations, such as in the southern hemisphere there is a slight downward trend between latitude and cloudiness which shows as latitude increases the cloudiness decreases.
