# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?" + "appid=" + weather_api_key + "&q="
units = "&units=imperial"

print("Beginning Data Retrieval")
print("------------------------------")

city_name = []
latitude = []
longitude = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
weather_date = []

for city in cities:
    try:
        response = requests.get(url + city + units).json()
        city_name.append(response['name'])
        city_id = response['id']
        city = response['name']
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        weather_date.append(response['dt'])
        print(f"Processing Record {city_id} | {city}")
    
    except:
        print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 3469058 | Brasília
# Processing Record 1507390 | Dikson
# Processing Record 2206939 | Bluff
# Processing Record 3874787 | Punta Arenas
# Processing Record 1517637 | Ushtobe
# Processing Record 2303611 | Esim
# City not found. Skipping...
# Processing Record 1263752 | Māngrol
# City not found. Skipping...
# Processing Record 1529484 | Kumul
# Processing Record 3366880 | Hermanus
# Processing Record 3430863 | Mar del Plata
# Processing Record 3622716 | Nicoya
# Processing Record 4032243 | Vaini
# Processing Record 2017155 | Saskylakh
# City not found. Skipping...
# Processing Record 4034551 | Faanui
# Processing Record 1337610 | Thinadhoo
# Processing Record 546105 | Nikolskoye
# Processing Record 4031574 | Provideniya
# Processing Record 933726 | Tshane
# Processing Record 3833367 | Ushuaia
# Processing Record 5044290 | Saint Anthony
# Processing Record 104515 | Makkah al Mukarramah
# Processing Record 525426 | Sobolevo
# Processing Record 2374583 | Bubaque
# Processing Record 5855927 | Hilo
# Processing Record 4030556 | Rikitea
# Processing Record 5563839 | Fortuna
# Processing Record 3883457 | Lebu
# Processing Record 964420 | Port Elizabeth
# Processing Record 3901903 | Uyuni
# Processing Record 1283581 | Kalaiya
# Processing Record 2094342 | Kavieng
# Processing Record 515879 | Oktyabr'skiy
# Processing Record 3424607 | Tasiilaq
# Processing Record 5106841 | Albany
# Processing Record 2033602 | Xiuyan
# Processing Record 6201424 | Mataura
# Processing Record 149703 | Sumbawanga
# Processing Record 2112802 | Hasaki
# Processing Record 5557293 | Sitka
# Processing Record 2126123 | Chokurdakh
# Processing Record 2208248 | Kaitangata
# Processing Record 2137773 | Vao
# Processing Record 2110227 | Butaritari
# Processing Record 4036284 | Alofi
# Processing Record 3372472 | Vila Franca do Campo
# Processing Record 2075265 | Busselton
# Processing Record 5354943 | Half Moon Bay
# Processing Record 2638312 | Seafield
# Processing Record 3939761 | Hualmay
# Processing Record 3374210 | São Filipe
# City not found. Skipping...
# Processing Record 3665202 | Aripuanã
# Processing Record 3445026 | Vila Velha
# Processing Record 3466704 | Castro
# Processing Record 3471451 | Arraial do Cabo
# Processing Record 962367 | Richards Bay
# Processing Record 4588165 | Mt. Pleasant
# Processing Record 3835869 | Santiago del Estero
# Processing Record 2180815 | Tuatapere
# Processing Record 1642773 | Japura
# Processing Record 3628473 | San Cristobal
# City not found. Skipping...
# Processing Record 6185377 | Yellowknife
# Processing Record 2122090 | Pevek
# Processing Record 1106677 | Bambous Virieux
# City not found. Skipping...
# Processing Record 1489656 | Teya
# Processing Record 2163355 | Hobart
# Processing Record 2155415 | New Norfolk
# Processing Record 5870133 | Nome
# Processing Record 3984997 | San Quintín
# Processing Record 3374083 | Bathsheba
# Processing Record 3381538 | Grand-Santi
# Processing Record 1214488 | Meulaboh
# Processing Record 3831208 | Qaanaaq
# Processing Record 1634614 | Nabire
# Processing Record 687726 | Zaozyornoye
# Processing Record 3421719 | Narsaq
# Processing Record 2109528 | Buala
# Processing Record 5848280 | Kapaa
# Processing Record 6050066 | La Ronge
# Processing Record 3408064 | Remanso
# Processing Record 3369157 | Cape Town
# Processing Record 3136023 | Storsteinnes
# Processing Record 4013679 | Coahuayana Viejo
# Processing Record 2036933 | Helong
# Processing Record 1735106 | George Town
# Processing Record 1054463 | Tsiroanomandidy
# Processing Record 108410 | Riyadh
# Processing Record 3985168 | San Patricio
# Processing Record 610864 | Khani
# Processing Record 57000 | Hobyo
# Processing Record 6089245 | Norman Wells
# Processing Record 3443061 | Chui
# Processing Record 2156643 | Mount Gambier
# Processing Record 1015776 | Bredasdorp
# Processing Record 2738381 | Lata
# Processing Record 6170031 | Tuktoyaktuk
# City not found. Skipping...
# Processing Record 4035715 | Avarua
# Processing Record 2155562 | Nelson Bay
# Processing Record 4255151 | Bud
# City not found. Skipping...
# Processing Record 2015217 | Tokur
# Processing Record 364933 | Umm Kaddadah
# Processing Record 2015306 | Tiksi
# Processing Record 5880054 | Barrow
# Processing Record 4014914 | Cedral
# Processing Record 2109701 | Auki
# Processing Record 2120612 | Tigil'
# Processing Record 3466165 | Cidreira
# Processing Record 1806408 | Yangjiang
# Processing Record 2396853 | Omboué
# Processing Record 3932145 | Pisco
# Processing Record 3423146 | Ilulissat
# Processing Record 1282256 | Hithadhoo
# Processing Record 935215 | Saint-Philippe
# Processing Record 2122574 | Ola
# Processing Record 5866583 | Saint Paul Harbor
# Processing Record 1862505 | Hirara
# Processing Record 1082243 | Ambilobe
# Processing Record 2070998 | Geraldton
# Processing Record 293842 | Kiryat Gat
# Processing Record 3104324 | Zaragoza
# Processing Record 2618795 | Klaksvík
# Processing Record 5505411 | Henderson
# Processing Record 2392087 | Porto-Novo
# City not found. Skipping...
# Processing Record 2123278 | Mil'kovo
# Processing Record 1696105 | Palimbang
# City not found. Skipping...
# Processing Record 2087894 | Rabaul
# Processing Record 3381041 | Mana
# Processing Record 2304548 | Anloga
# City not found. Skipping...
# Processing Record 2236967 | Soyo
# Processing Record 1510689 | Baykit
# Processing Record 7626381 | Klæbu
# Processing Record 5546220 | Saint George
# Processing Record 2074865 | Carnarvon
# Processing Record 3652764 | Puerto Ayora
# Processing Record 1516589 | Zhezkazgan
# Processing Record 1650527 | Balikpapan
# Processing Record 1511736 | Altayskoye
# Processing Record 2179103 | Whitianga
# Processing Record 3649833 | Acarigua
# Processing Record 1651810 | Airai
# Processing Record 3893629 | Coquimbo
# Processing Record 4954611 | Watertown
# Processing Record 2654970 | Brae
# City not found. Skipping...
# Processing Record 107304 | Buraidah
# Processing Record 1515029 | Ulaangom
# Processing Record 2121385 | Severo-Kuril'sk
# Processing Record 3418910 | Upernavik
# City not found. Skipping...
# Processing Record 1159716 | Sarakhs
# Processing Record 4360369 | Laurel
# Processing Record 4001956 | La Huacana
# City not found. Skipping...
# Processing Record 2399001 | Mayumba
# Processing Record 4115181 | Hope
# Processing Record 5955902 | Fort Nelson
# Processing Record 3936456 | Lima
# Processing Record 3380290 | Sinnamary
# Processing Record 964432 | Port Alfred
# Processing Record 5122534 | Jamestown
# Processing Record 5847411 | Kahului
# Processing Record 1490256 | Talnakh
# Processing Record 1812988 | Dengzhou
# Processing Record 2399371 | Makokou
# Processing Record 2108502 | Honiara
# Processing Record 2640377 | Penzance
# Processing Record 2094027 | Kieta
# Processing Record 2281120 | Tabou
# Processing Record 2167426 | Emerald
# Processing Record 3114567 | Palafrugell
# Processing Record 1185128 | Rajshahi
# Processing Record 5866063 | Kenai
# Processing Record 3361934 | Saldanha
# Processing Record 3355672 | Lüderitz
# Processing Record 2177254 | Bagotville
# Processing Record 784227 | Veliki Trnovac
# Processing Record 534245 | Lopandino
# Processing Record 3893726 | Constitución
# Processing Record 187896 | Mandera
# Processing Record 779622 | Havøysund
# Processing Record 2171099 | Codrington
# Processing Record 1732826 | Mersing
# Processing Record 53654 | Mogadishu
# Processing Record 6165406 | Thompson
# Processing Record 3465145 | Crixás
# Processing Record 3409644 | Corrente
# Processing Record 2240449 | Luanda
# City not found. Skipping...
# Processing Record 2630299 | Hofn
# Processing Record 2729907 | Longyearbyen
# Processing Record 4845585 | Westport
# Processing Record 3451138 | Rio Grande
# Processing Record 6255012 | Flinders
# Processing Record 2643044 | Margate
# Processing Record 3985710 | Cabo San Lucas
# Processing Record 2258378 | Loandjili
# Processing Record 1734705 | Kuala Terengganu
# City not found. Skipping...
# Processing Record 2152659 | Port Macquarie
# Processing Record 933995 | Souillac
# City not found. Skipping...
# Processing Record 2636790 | Stornoway
# Processing Record 6355222 | Yulara
# Processing Record 2013465 | Verkhoyansk
# Processing Record 2019118 | Nizhniy Tsasuchey
# Processing Record 986717 | Kruisfontein
# Processing Record 368246 | Raja
# Processing Record 3466980 | Caravelas
# City not found. Skipping...
# Processing Record 2148431 | Stawell
# Processing Record 2312249 | Mushie
# Processing Record 124647 | Bardsīr
# Processing Record 6949678 | Taitung City
# Processing Record 5850554 | Makakilo City
# Processing Record 2638785 | St Helens
# Processing Record 2126199 | Cherskiy
# Processing Record 921786 | Mitsamiouli
# Processing Record 2062276 | Roebourne
# Processing Record 1184655 | Alipur
# City not found. Skipping...
# Processing Record 905789 | Mpongwe
# Processing Record 1337605 | Mahibadhoo
# Processing Record 1701054 | Marawi
# Processing Record 2177069 | Ballina
# City not found. Skipping...
# Processing Record 2018735 | Nyurba
# Processing Record 2276492 | Harper
# Processing Record 287832 | Ibrā’
# Processing Record 3448903 | São João da Barra
# Processing Record 2161515 | Kiama
# Processing Record 5962442 | Goderich
# Processing Record 6137462 | Saint-Augustin
# City not found. Skipping...
# Processing Record 1529376 | Korla
# Processing Record 2448083 | Agadez
# Processing Record 3115824 | Muros
# Processing Record 578045 | Belinsky
# Processing Record 2092164 | Lorengau
# City not found. Skipping...
# Processing Record 5859699 | College
# Processing Record 2629833 | Husavik
# Processing Record 286621 | Salalah
# Processing Record 156098 | Laela
# Processing Record 3129877 | Aranda de Duero
# Processing Record 3860443 | Comodoro Rivadavia
# Processing Record 3694112 | Paita
# Processing Record 2067119 | Mandurah
# Processing Record 3576994 | Cockburn Town
# Processing Record 3879429 | Monte Patria
# Processing Record 1317402 | Kyaikkami
# City not found. Skipping...
# Processing Record 3996426 | Matamoros
# Processing Record 2126710 | Beringovskiy
# Processing Record 1831112 | Kampot
# Processing Record 2136825 | Isangel
# Processing Record 1513491 | Yangi Marg`ilon
# Processing Record 1563281 | Tuy Hoa
# Processing Record 5969025 | Haines Junction
# Processing Record 2181625 | Te Anau
# Processing Record 3633444 | Machiques
# Processing Record 286245 | Sur
# Processing Record 3347719 | Luena
# Processing Record 3137469 | Sørland
# Processing Record 6167817 | Torbay
# Processing Record 2027296 | Aykhal
# Processing Record 1242110 | Kalmunai
# Processing Record 1066310 | Betioky
# City not found. Skipping...
# Processing Record 472887 | Vokhma
# Processing Record 1636022 | Martapura
# City not found. Skipping...
# Processing Record 2790153 | Nieuwpoort
# Processing Record 3573374 | The Valley
# Processing Record 140097 | Borazjan
# Processing Record 3836669 | San Rafael
# Processing Record 1798760 | Pingliang
# Processing Record 1203344 | Farīdpur
# City not found. Skipping...
# Processing Record 2071860 | Esperance
# City not found. Skipping...
# Processing Record 5913695 | Cambridge
# Processing Record 4951594 | Southbridge
# Processing Record 2537881 | Safi
# Processing Record 1801722 | Lüshunkou
# Processing Record 3675504 | Manaure
# Processing Record 3372707 | Ribeira Grande
# Processing Record 304825 | Manisa Province
# Processing Record 162627 | Yabrūd
# Processing Record 1801615 | Maba
# Processing Record 1626542 | Sorong
# Processing Record 2194098 | Ahipara
# Processing Record 215976 | Ilebo
# City not found. Skipping...
# Processing Record 2396518 | Port-Gentil
# Processing Record 921889 | Fomboni
# City not found. Skipping...
# Processing Record 2037252 | Genhe
# Processing Record 1006984 | East London
# Processing Record 2209055 | Waddān
# Processing Record 3421765 | Nanortalik
# Processing Record 4673258 | Beeville
# Processing Record 1861280 | Itoman
# Processing Record 3402648 | Carutapera
# Processing Record 86049 | Jalu
# Processing Record 6690297 | Saint-Leu
# Processing Record 1819729 | Hong Kong
# Processing Record 2132606 | Samarai
# Processing Record 4020109 | Atuona
# Processing Record 5808079 | Redmond
# Processing Record 934322 | Mahébourg
# Processing Record 3404558 | Cabedelo
# Processing Record 2068110 | Kununurra
# Processing Record 2036338 | Kaitong
# Processing Record 3369174 | Calvinia
# Processing Record 5610810 | Twin Falls
# Processing Record 3492985 | Santa Cruz de Barahona
# Processing Record 713389 | Horodkivka
# Processing Record 3374351 | Pombas
# Processing Record 935214 | Saint-Pierre
# Processing Record 2064735 | Nhulunbuy
# Processing Record 4575352 | Columbia
# Processing Record 2065594 | Mount Isa
# Processing Record 3430545 | Morón
# Processing Record 2034497 | Guangming
# Processing Record 5991056 | Kenora
# Processing Record 1271533 | Gariadhar
# Processing Record 4189423 | Cordele
# Processing Record 556268 | Ostrovnoy
# Processing Record 2015913 | Suntar
# Processing Record 866241 | Myskhako
# Processing Record 3547260 | Media Luna
# Processing Record 7671223 | Kloulklubed
# Processing Record 6144312 | Sept-Îles
# Processing Record 5856516 | ‘Āhuimanu
# Processing Record 1634718 | Muncar
# Processing Record 1267390 | Kavaratti
# Processing Record 3401845 | Conceição do Araguaia
# Processing Record 3625066 | Zaraza
# Processing Record 6620339 | Karratha
# Processing Record 471501 | Vostochnyy
# Processing Record 5924351 | Clyde River
# Processing Record 5882953 | Aklavik
# Processing Record 1857751 | Maki
# Processing Record 2636638 | Stromness
# City not found. Skipping...
# Processing Record 5983720 | Iqaluit
# Processing Record 2961459 | Skibbereen
# Processing Record 1649150 | Bengkulu
# Processing Record 1252744 | Yellāpur
# Processing Record 336745 | Gewanē
# Processing Record 1254046 | Tura
# Processing Record 3372783 | Ponta Delgada
# Processing Record 3981391 | Tomatlán
# Processing Record 778707 | Mehamn
# City not found. Skipping...
# Processing Record 4957320 | Bar Harbor
# Processing Record 1812728 | Dingzhou
# Processing Record 1487839 | Vakhrushevo
# Processing Record 2610343 | Vestmanna
# Processing Record 1847947 | Shingū
# Processing Record 2022572 | Khatanga
# City not found. Skipping...
# Processing Record 1259385 | Port Blair
# Processing Record 2377450 | Nouakchott
# Processing Record 315720 | Elmadağ
# Processing Record 1222396 | Kuah
# Processing Record 1794971 | Shitanjing
# City not found. Skipping...
# Processing Record 1852357 | Shimoda
# Processing Record 3580733 | Bodden Town
# Processing Record 490068 | Sovetsk
# Processing Record 3372964 | Lagoa
# Processing Record 612592 | Oni
# Processing Record 777019 | Vardø
# Processing Record 2090021 | Namatanai
# Processing Record 5746545 | Portland
# City not found. Skipping...
# Processing Record 2264557 | Ponta do Sol
# Processing Record 5967157 | Grimshaw
# Processing Record 2283016 | Odienné
# Processing Record 1688696 | San Policarpo
# Processing Record 2446796 | Bilma
# City not found. Skipping...
# Processing Record 3994535 | Ocampo
# Processing Record 53372 | Oodweyne
# Processing Record 933182 | Palapye
# Processing Record 2294915 | Takoradze
# Processing Record 4272788 | Haysville
# Processing Record 1805518 | Jining
# Processing Record 1283240 | Kathmandu
# Processing Record 2135517 | Norsup
# Processing Record 6111862 | Port Hardy
# Processing Record 3386213 | Touros
# Processing Record 5959335 | Gander
# Processing Record 1162634 | Wana
# Processing Record 934479 | Grand Gaube
# Processing Record 1714733 | Dingle
# Processing Record 4152311 | Crestview
# Processing Record 2388036 | Bossangoa
# Processing Record 1213855 | Sibolga
# Processing Record 1539209 | Gubkinskiy
# Processing Record 159134 | Inyonga
# Processing Record 5367788 | Lompoc
# Processing Record 475463 | Verkhneural'sk
# Processing Record 1492566 | Severo-Yeniseyskiy
# Processing Record 2185329 | Otane
# City not found. Skipping...
# Processing Record 3992842 | Petatlán
# Processing Record 110690 | Abhā
# Processing Record 2179825 | Waitati
# Processing Record 2155858 | Nambucca Heads
# City not found. Skipping...
# Processing Record 2641108 | Oban
# Processing Record 3407216 | Arcoverde
# Processing Record 3430443 | Necochea
# Processing Record 2862118 | Norden
# Processing Record 1519938 | Karatau
# Processing Record 1622318 | Waingapu
# Processing Record 1863997 | Fukuechō
# Processing Record 2514651 | Los Llanos de Aridane
# Processing Record 5688025 | Bismarck
# Processing Record 6113406 | Prince Rupert
# Processing Record 3870243 | Taltal
# Processing Record 2381334 | Atar
# Processing Record 60019 | Eyl
# Processing Record 486186 | Suoyarvi
# Processing Record 1264647 | Mācherla
# Processing Record 2688368 | Norrköping
# Processing Record 3398856 | Grajaú
# Processing Record 3407357 | Araguaína
# Processing Record 2234339 | Bétaré Oya
# Processing Record 1498161 | Muzhi
# Processing Record 3395458 | Maragogi
# Processing Record 3921141 | Charagua
# Processing Record 2027042 | Batagay-Alyta
# Processing Record 1337606 | Eydhafushi
# Processing Record 5975004 | High Level
# Processing Record 3899695 | Ancud
# Processing Record 1495385 | Pelym
# Processing Record 866062 | Iskateley
# Processing Record 7647007 | Bariloche
# Processing Record 1488903 | Turukhansk
# Processing Record 3421193 | Paamiut
# Processing Record 2012530 | Zhigansk
# Processing Record 3899539 | Antofagasta
# Processing Record 2270385 | Camacha
# Processing Record 258241 | Lithakia
# Processing Record 676557 | Gura Caliţei
# Processing Record 1512019 | Aksarka
# Processing Record 3464008 | Esmeraldas
# Processing Record 360502 | Luxor
# Processing Record 2013442 | Vershino-Darasunskiy
# Processing Record 3412093 | Vestmannaeyjar
# City not found. Skipping...
# Processing Record 4004293 | Ixtapa
# Processing Record 2019135 | Nizhniy Kuranakh
# Processing Record 3620661 | Bocana de Paiwas
# Processing Record 1337613 | Kulhudhuffushi
# Processing Record 1538641 | Kedrovyy
# Processing Record 779330 | Kautokeino
# Processing Record 643492 | Oulu
# Processing Record 709643 | Drabiv
# Processing Record 64814 | Bandarbeyla
# Processing Record 3466703 | Castro Alves
# Processing Record 4362001 | Mayo
# City not found. Skipping...
# Processing Record 1650434 | Bambanglipuro
# Processing Record 5282297 | Bethel
# City not found. Skipping...
# Processing Record 2055868 | Yantal'
# Processing Record 6162949 | Terrace
# Processing Record 1526041 | Atasū
# Processing Record 3533462 | Acapulco de Juárez
# City not found. Skipping...
# Processing Record 3393692 | Itarema
# Processing Record 2146219 | Hervey Bay
# City not found. Skipping...
# Processing Record 2013727 | Vanavara
# Processing Record 2409914 | Bonthe
# Processing Record 5935341 | Dauphin
# Processing Record 740263 | Samsun Province
# Processing Record 1688781 | City of San Pedro
# Processing Record 1065158 | Farafangana
# Processing Record 1528998 | Yumen
# Processing Record 2656847 | Atherton
# Processing Record 260895 | Karpathos
# Processing Record 1990589 | Teluknaga
# City not found. Skipping...
# Processing Record 3904906 | Santa Cruz de la Sierra
# Processing Record 1795632 | Shenjiamen
# Processing Record 3136765 | Hell
# Processing Record 2063036 | Port Lincoln
# Processing Record 3893894 | Concepción
# Processing Record 3421982 | Maniitsoq
# Processing Record 6100799 | Pemberton
# Processing Record 1508811 | Bredy
# Processing Record 2016680 | Shirokiy
# City not found. Skipping...
# Processing Record 1640902 | Kawalu
# City not found. Skipping...
# Processing Record 2157698 | Mildura
# Processing Record 6542282 | Genoa
# Processing Record 4389658 | Harrisonville
# Processing Record 184379 | Narok
# Processing Record 3480908 | La Asuncion
# Processing Record 3834601 | Tartagal
# Processing Record 3442778 | Delta del Tigre
# Processing Record 2077895 | Alice Springs
# Processing Record 3392657 | Pedra
# Processing Record 5516233 | Amarillo
# Processing Record 542184 | Krasnovishersk
# Processing Record 2377457 | Nouadhibou
# Processing Record 299817 | Tarsus
# Processing Record 3691954 | Sechura
# Processing Record 2331447 | Maiduguri
# Processing Record 2222230 | Sangmélima
# Processing Record 2015852 | Svetlaya
# Processing Record 680831 | Cordun
# Processing Record 3517970 | Pochutla
# Processing Record 2189343 | Kaeo
# Processing Record 5055787 | Kirksville
# Processing Record 2016412 | Smidovich
# Processing Record 3121424 | Gijón
# Processing Record 3419842 | Sisimiut
# Processing Record 3698359 | Chicama
# Processing Record 3902377 | La Santisima Trinidad
# Processing Record 5380437 | Pacific Grove
# Processing Record 2426370 | Umm Hājar
# Processing Record 186180 | Moyale
# City not found. Skipping...
# Processing Record 3976161 | Adolfo López Mateos
# Processing Record 1734971 | Pekan
# Processing Record 582222 | Amzya
# Processing Record 5530022 | San Angelo
# Processing Record 2639912 | Preston
# Processing Record 2126682 | Bilibino
# Processing Record 161901 | Kaka
# Processing Record 933416 | Manyana
# Processing Record 1283465 | Dhankutā
# Processing Record 708898 | Hayvoron
# Processing Record 3175096 | Laas
# Processing Record 686090 | Asău
# Processing Record 217834 | Bukama
# Processing Record 5391295 | Salinas
# Processing Record 2083537 | Wewak
# Processing Record 2374688 | Bolama
# Processing Record 2649738 | Fairlie
# Processing Record 2192362 | Christchurch
# Processing Record 2253354 | Dakar
# Processing Record 124291 | Mehrān
# Processing Record 3168075 | San Marco in Lamis
# Processing Record 2178753 | Kirakira
# City not found. Skipping...
# Processing Record 3391908 | Piripiri
# Processing Record 3430708 | Mercedes
# Processing Record 5983607 | Inuvik
# Processing Record 3356832 | Henties Bay
# Processing Record 3347019 | Mossamedes
# Processing Record 2123814 | Leningradskiy
# Processing Record 3728097 | Les Cayes
# Processing Record 1731248 | Alugan
# Processing Record 2079582 | Alyangula
# Processing Record 2023584 | Imeni Poliny Osipenko
# Processing Record 2013918 | Ust-Maya
# Processing Record 2516474 | Icod de los Vinos
# City not found. Skipping...
# Processing Record 1818051 | Anjiang
# Processing Record 1795196 | Tongchuanshi
# Processing Record 281133 | Gaza
# Processing Record 1278149 | Aurangabad
# Processing Record 2088659 | Panguna
# Processing Record 4231997 | Avera
# Processing Record 3870282 | Talcahuano
# Processing Record 2026696 | Bikin
# Processing Record 110690 | Faya
# Processing Record 3108125 | Teruel
# Processing Record 4031637 | Lavrentiya
# Processing Record 14177 | Maku
# Processing Record 2294877 | Tamale
# Processing Record 2121909 | Poronaysk
# Processing Record 607610 | Zhangaözen
# Processing Record 3580477 | West Bay
# City not found. Skipping...
# Processing Record 3456138 | Nova Odessa
# Processing Record 3837056 | San Luis
# Processing Record 3395981 | Maceió
# Processing Record 3894426 | Coyhaique
# City not found. Skipping...
# Processing Record 2173323 | Bundaberg
# Processing Record 3456137 | Nova Olímpia
# Processing Record 2644210 | Liverpool
# Processing Record 155848 | Longido
# Processing Record 3470871 | Barão de Melgaço
# Processing Record 2120591 | Tilichiki
# Processing Record 3454763 | Patrocínio
# Processing Record 946257 | Ulundi
# Processing Record 6180550 | Whitehorse
# Processing Record 2067089 | Maningrida
# City not found. Skipping...
# Processing Record 4031742 | Egvekinot
# Processing Record 2136150 | Luganville
# City not found. Skipping...
# Processing Record 477940 | Ust-Tsilma

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data_df = pd.DataFrame({
    "City":city_name,
    "Lat":latitude,
    "Lon":longitude,
    "Max Temp":max_temp,
    "Humidity":humidity,
    "Cloudiness":cloudiness,
    "Wind Speed":wind_speed,
    "Country":country,
    "Date":weather_date     
})

weather_data_df.count()
# Out:
# City          561
# Lat           561
# Lon           561
# Max Temp      561
# Humidity      561
# Cloudiness    561
# Wind Speed    561
# Country       561
# Date          561
# dtype: int64

# %%
weather_data_df.head()
# Out:
#            City    Lat     Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Brasília -15.78  -47.93     82.40        34          40        6.93
# 1        Dikson  73.51   80.55     41.97        97          98        5.86
# 2         Bluff -46.60  168.33     39.00        83          72        3.00
# 3  Punta Arenas -53.15  -70.92     39.20        79          40       17.22
# 4       Ushtobe  45.25   77.98     67.33        43           0        8.16
#
#   Country        Date
# 0      BR  1594580128
# 1      RU  1594579916
# 2      NZ  1594580214
# 3      CL  1594580214
# 4      KZ  1594580067

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_data_df.describe()
# Out:
#               Lat         Lon    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  561.000000  561.000000  561.000000  561.000000  561.000000  561.000000
# mean    18.661765   19.387433   69.701408   69.119430   49.704100    8.133440
# std     33.541616   90.649661   14.395691   20.726148   39.738001    5.260855
# min    -54.800000 -179.170000   32.760000    3.000000    0.000000    0.600000
# 25%     -8.840000  -58.650000   58.230000   56.000000    5.000000    4.120000
# 50%     20.890000   21.880000   71.600000   73.000000   40.000000    6.890000
# 75%     47.670000  102.270000   80.600000   87.000000   90.000000   11.410000
# max     78.220000  179.320000  109.400000  100.000000  100.000000   33.040000
#
#                Date
# count  5.610000e+02
# mean   1.594580e+09
# std    1.780561e+02
# min    1.594579e+09
# 25%    1.594580e+09
# 50%    1.594580e+09
# 75%    1.594580e+09
# max    1.594580e+09

# %%
# Make a new DataFrame to drop any cities with a humidity greather than 100
lower_humidity_df = weather_data_df.loc[weather_data_df["Humidity"] <= 100, :]

lower_humidity_df.to_csv("output_data/WeatherData.csv", index=False, header=True)

lower_humidity_df.head()
# Out:
#            City    Lat     Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Brasília -15.78  -47.93     82.40        34          40        6.93
# 1        Dikson  73.51   80.55     41.97        97          98        5.86
# 2         Bluff -46.60  168.33     39.00        83          72        3.00
# 3  Punta Arenas -53.15  -70.92     39.20        79          40       17.22
# 4       Ushtobe  45.25   77.98     67.33        43           0        8.16
#
#   Country        Date
# 0      BR  1594580128
# 1      RU  1594579916
# 2      NZ  1594580214
# 3      CL  1594580214
# 4      KZ  1594580067

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
today_date = pd.to_datetime('today').strftime("%m/%d/%Y")

plt.scatter(lower_humidity_df["Lat"],lower_humidity_df["Max Temp"], edgecolor = 'black')
plt.grid(color="black", linewidth=1,alpha=0.20)
plt.title("City Latitude vs Max Temperature (" + today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.savefig("output_data/LatitudeVSMaxTemperature.png")
plt.show()

# %% [markdown]
# #### The graph is showing the correlation between latitude and maximum tempature. The closer to the equator (0 Latitude), the hotter the temperatures.

# %%
plt.scatter(lower_humidity_df["Lat"],lower_humidity_df["Humidity"], edgecolor = 'black')
plt.grid(color="black", linewidth=1,alpha=0.20)
plt.title("City Latitude vs Humidity (" + today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.savefig("output_data/LatitudeVSHumidity.png")
plt.show()

# %% [markdown]
# #### The graph is showing the correlation between latitude and humidity. There does not appear to be a correlation between latitude and humidity.

# %%
plt.scatter(lower_humidity_df["Lat"],lower_humidity_df["Cloudiness"], edgecolor = 'black')
plt.grid(color="black", linewidth=1,alpha=0.20)
plt.title("City Latitude vs Cloudiness (" + today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.savefig("output_data/LatitudeVSCloudiness.png")
plt.show()

# %% [markdown]
# #### The graph is showing the correlation between latitude and cloudiness. There does not appear to be a correlation between latitude and cloudiness.

# %%
plt.scatter(lower_humidity_df["Lat"],lower_humidity_df["Wind Speed"], edgecolor = 'black')
plt.grid(color="black", linewidth=1,alpha=0.20)
plt.title("City Latitude vs Wind Speed (" + today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig("output_data/LatitudeVSWindSpeed.png")
plt.show()

# %% [markdown]
# #### The graph is showing the correlation between latitude and wind speed. It appears no matter what latitude the wind speeds are lower with a few outliers.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def hemp_regression(x_values,y_values,y_axis_name,hemisphere):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(x_values.min(), y_values.min()),fontsize=15,color="red")
    plt.title(hemisphere + " - " + y_axis_name + " vs. Latitude Linear Regression")
    plt.xlabel("Latitude")
    plt.ylabel(y_axis_name)
    print(f"The r-squared is: {rvalue**2}")
    plt.savefig("output_data/Regression_"+ hemisphere + "_LatitudeVs" + y_axis_name + ".png")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere_df = lower_humidity_df.loc[lower_humidity_df["Lat"] >= 0, :]
northern_hemisphere_df.head()
# Out:
#       City    Lat    Lon  Max Temp  Humidity  Cloudiness  Wind Speed Country  \
# 1   Dikson  73.51  80.55     41.97        97          98        5.86      RU
# 4  Ushtobe  45.25  77.98     67.33        43           0        8.16      KZ
# 5     Esim   4.87  -2.24     74.75        87          39        6.89      GH
# 6  Māngrol  21.12  70.12     83.80        81          75       16.08      IN
# 7    Kumul  42.80  93.45     77.56        35          27        8.72      CN
#
#          Date
# 1  1594579916
# 4  1594580067
# 5  1594579494
# 6  1594580214
# 7  1594579623

# %%
# Create Northern and Southern Hemisphere DataFrames
southern_hemisphere_df = lower_humidity_df.loc[lower_humidity_df["Lat"] < 0, :]
southern_hemisphere_df.head()
# Out:
#             City    Lat     Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Brasília -15.78  -47.93     82.40        34          40        6.93
# 2          Bluff -46.60  168.33     39.00        83          72        3.00
# 3   Punta Arenas -53.15  -70.92     39.20        79          40       17.22
# 8       Hermanus -34.42   19.23     55.99        56           0       14.00
# 9  Mar del Plata -38.00  -57.56     50.00        39          20       19.46
#
#   Country        Date
# 0      BR  1594580128
# 2      NZ  1594580214
# 3      CL  1594580214
# 8      ZA  1594580215
# 9      AR  1594579976

# %%
hemp_regression(northern_hemisphere_df["Lat"],northern_hemisphere_df["Max Temp"],"Max Temp","Northern Hemisphere")
# Out:
# The r-squared is: 0.5506218319311037

# %%
hemp_regression(southern_hemisphere_df["Lat"],southern_hemisphere_df["Max Temp"],"Max Temp","Southern Hemisphere")
# Out:
# The r-squared is: 0.6220333857634367

# %% [markdown]
# #### In both hemispheres, there appears to be a direct correlation between latitude and temperature. As the latitude increases the temperature decreases and as the latitude decreases the temperature increases.

# %%
hemp_regression(northern_hemisphere_df["Lat"],northern_hemisphere_df["Humidity"],"Humidity","Northern Hemisphere")
# Out:
# The r-squared is: 0.010293586774281143

# %%
hemp_regression(southern_hemisphere_df["Lat"],southern_hemisphere_df["Humidity"],"Humidity","Southern Hemisphere")
# Out:
# The r-squared is: 0.001448207606874349

# %% [markdown]
# #### There appears to be no correlation between latitude and humidity. The regression lines are pretty straight showing there is no way of determing humidity based on latitude and vice versa.

# %%
hemp_regression(northern_hemisphere_df["Lat"],northern_hemisphere_df["Cloudiness"],"Cloudiness","Northern Hemisphere")
# Out:
# The r-squared is: 0.0018178023012452573

# %%
hemp_regression(southern_hemisphere_df["Lat"],southern_hemisphere_df["Cloudiness"],"Cloudiness","Southern Hemisphere")
# Out:
# The r-squared is: 0.016703501574399746

# %% [markdown]
# #### In the northern hemisphere, the regression line is almost flat which shows there is not much of a correlation between latitude and cloudiness. In the southern hemisphere, the line has a slight upward trend which denotes that as latitude decreases the cloudiness increases.

# %%
hemp_regression(northern_hemisphere_df["Lat"],northern_hemisphere_df["Wind Speed"],"Wind Speed","Northern Hemisphere")
# Out:
# The r-squared is: 0.0048033731541895245

# %%
hemp_regression(southern_hemisphere_df["Lat"],southern_hemisphere_df["Wind Speed"],"Wind Speed","Southern Hemisphere")
# Out:
# The r-squared is: 0.021655463738930396

# %% [markdown]
# #### In both hemispheres, the regression lines have a slight downward trend which denotes that as latitude decreases the wind speed decreases as well.
