# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?" + "appid=" + weather_api_key + "&q="
units = "&units=imperial"

print("Beginning Data Retrieval")
print("------------------------------")

city_name = []
latitude = []
longitude = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
weather_date = []

for city in cities:
    try:
        response = requests.get(url + city + units).json()
        city_name.append(response['name'])
        city_id = response['id']
        city = response['name']
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        weather_date.append(response['dt'])
        print(f"Processing Record {city_id} | {city}")
    
    except:
        print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 2136825 | Isangel
# Processing Record 546105 | Nikolskoye
# Processing Record 2194098 | Ahipara
# Processing Record 1819729 | Hong Kong
# Processing Record 556268 | Ostrovnoy
# Processing Record 2126123 | Chokurdakh
# Processing Record 2618795 | Klaksvík
# Processing Record 2075265 | Busselton
# Processing Record 5122534 | Jamestown
# Processing Record 4020109 | Atuona
# Processing Record 2738381 | Lata
# Processing Record 2381334 | Atar
# Processing Record 1633419 | Padang
# Processing Record 2126710 | Beringovskiy
# City not found. Skipping...
# Processing Record 3833367 | Ushuaia
# Processing Record 1015776 | Bredasdorp
# Processing Record 5106841 | Albany
# Processing Record 6111862 | Port Hardy
# Processing Record 3874787 | Punta Arenas
# City not found. Skipping...
# Processing Record 1151464 | Phang Nga
# Processing Record 5282297 | Bethel
# Processing Record 4035715 | Avarua
# Processing Record 1252668 | Ziro
# Processing Record 4030556 | Rikitea
# Processing Record 2325314 | Owo
# Processing Record 6089245 | Norman Wells
# Processing Record 1644178 | Genteng
# Processing Record 2521582 | Arona
# Processing Record 212902 | Kindu
# Processing Record 2180815 | Tuatapere
# City not found. Skipping...
# Processing Record 4032243 | Vaini
# Processing Record 3571913 | Marsh Harbour
# Processing Record 1264363 | Mahmudābād
# Processing Record 3111607 | Ripoll
# Processing Record 1507390 | Dikson
# Processing Record 2381972 | Adrar
# Processing Record 504409 | Pryazha
# Processing Record 777019 | Vardø
# City not found. Skipping...
# Processing Record 1528998 | Yumen
# Processing Record 5546220 | Saint George
# Processing Record 5848280 | Kapaa
# Processing Record 1490256 | Talnakh
# Processing Record 4021858 | Guerrero Negro
# Processing Record 2162683 | Innisfail
# City not found. Skipping...
# Processing Record 3430863 | Mar del Plata
# Processing Record 3424607 | Tasiilaq
# Processing Record 2032614 | Baruun-Urt
# Processing Record 5882953 | Aklavik
# Processing Record 5855927 | Hilo
# Processing Record 2206939 | Bluff
# Processing Record 703845 | Kryvyi Rih
# Processing Record 4333811 | Morgan City
# Processing Record 6201424 | Mataura
# Processing Record 2836320 | Schorndorf
# Processing Record 2121385 | Severo-Kuril'sk
# Processing Record 3372707 | Ribeira Grande
# Processing Record 3382160 | Cayenne
# City not found. Skipping...
# Processing Record 3663475 | Maraã
# Processing Record 2094144 | Kerema
# City not found. Skipping...
# Processing Record 4852065 | Clive
# City not found. Skipping...
# Processing Record 107304 | Buraidah
# Processing Record 3985710 | Cabo San Lucas
# Processing Record 3424901 | Aasiaat
# Processing Record 3652764 | Puerto Ayora
# Processing Record 2074865 | Carnarvon
# Processing Record 783768 | Zvečka
# Processing Record 3520994 | Puerto Escondido
# Processing Record 1803331 | Linxia Chengguanzhen
# Processing Record 3416888 | Grindavik
# Processing Record 230893 | Kitgum
# Processing Record 1735106 | George Town
# Processing Record 2523738 | Polistena
# Processing Record 2264557 | Ponta do Sol
# Processing Record 86049 | Jalu
# Processing Record 2134814 | Sola
# Processing Record 3883457 | Lebu
# Processing Record 2098329 | Daru
# Processing Record 128234 | Kerman
# Processing Record 1058381 | Morondava
# Processing Record 2236967 | Soyo
# City not found. Skipping...
# Processing Record 4034496 | Fare
# Processing Record 5991056 | Kenora
# Processing Record 3366880 | Hermanus
# Processing Record 1623197 | Tual
# City not found. Skipping...
# Processing Record 2037886 | Dandong
# Processing Record 3374083 | Bathsheba
# Processing Record 554776 | Iznoski
# Processing Record 161290 | Bagamoyo
# Processing Record 1517323 | Zhanakorgan
# Processing Record 3996426 | Matamoros
# Processing Record 934479 | Grand Gaube
# Processing Record 2079582 | Alyangula
# Processing Record 2155562 | Nelson Bay
# City not found. Skipping...
# Processing Record 2177069 | Ballina
# Processing Record 2272189 | Alcanena
# Processing Record 1503037 | Kodinsk
# Processing Record 2014624 | Udachny
# Processing Record 3533462 | Acapulco de Juárez
# Processing Record 5563839 | Fortuna
# Processing Record 1106643 | Quatre Cocos
# Processing Record 1797318 | Qujing
# Processing Record 3421193 | Paamiut
# Processing Record 2015306 | Tiksi
# Processing Record 3984997 | San Quintín
# Processing Record 4031574 | Provideniya
# City not found. Skipping...
# Processing Record 567589 | Chupa
# Processing Record 3828545 | San José del Guaviare
# Processing Record 763107 | Gmina Opole Lubelskie
# Processing Record 1504343 | Karpinsk
# Processing Record 153955 | Micheweni
# City not found. Skipping...
# Processing Record 1489853 | Tazovsky
# Processing Record 1062663 | Mahajanga
# Processing Record 1040938 | Manjacaze
# Processing Record 546742 | Kodino
# Processing Record 2290849 | Bouna
# Processing Record 2070998 | Geraldton
# Processing Record 3175096 | Laas
# Processing Record 2097418 | Finschhafen
# Processing Record 2281120 | Tabou
# Processing Record 3421719 | Narsaq
# Processing Record 611219 | Vani
# Processing Record 1502073 | Krasnosel'kup
# Processing Record 3080866 | Zakopane
# Processing Record 1272610 | Dighwāra
# Processing Record 2181625 | Te Anau
# Processing Record 1649150 | Bengkulu
# Processing Record 1491230 | Sovetskiy
# City not found. Skipping...
# Processing Record 2015707 | Takhtamygda
# Processing Record 3147104 | Løding
# Processing Record 3932145 | Pisco
# Processing Record 4031637 | Lavrentiya
# Processing Record 4036284 | Alofi
# Processing Record 6355222 | Yulara
# Processing Record 2514651 | Los Llanos de Aridane
# Processing Record 624079 | Orsha
# Processing Record 8133974 | Perama
# Processing Record 6165406 | Thompson
# Processing Record 118063 | Sabzawār
# Processing Record 3059101 | Levice
# Processing Record 3461465 | Iguape
# Processing Record 3899695 | Ancud
# Processing Record 8079926 | Labuhan
# Processing Record 780643 | Bjørnevatn
# Processing Record 286621 | Salalah
# Processing Record 2181133 | Pareora
# Processing Record 3472177 | Angra dos Reis
# Processing Record 3530599 | Ciudad del Carmen
# Processing Record 3374210 | São Filipe
# Processing Record 3466165 | Cidreira
# Processing Record 1082243 | Ambilobe
# Processing Record 2122605 | Okhotsk
# Processing Record 1525988 | Ayagoz
# Processing Record 2033766 | Xingcheng
# Processing Record 3988265 | Sahuaripa
# Processing Record 1282256 | Hithadhoo
# Processing Record 2377457 | Nouadhibou
# Processing Record 553427 | Kamenolomni
# Processing Record 2088163 | Popondetta
# Processing Record 3105522 | Bereda
# Processing Record 3385758 | Umirim
# Processing Record 4845585 | Westport
# Processing Record 2186280 | Nelson
# Processing Record 2022572 | Khatanga
# Processing Record 70979 | Sayyan
# Processing Record 3445026 | Vila Velha
# Processing Record 2092164 | Lorengau
# Processing Record 3029029 | Arrondissement de Cambrai
# Processing Record 2303611 | Esim
# Processing Record 1650527 | Balikpapan
# Processing Record 352733 | Marsá Maţrūḩ
# Processing Record 2126199 | Cherskiy
# Processing Record 1056899 | Sambava
# Processing Record 3855065 | General Roca
# Processing Record 6255012 | Flinders
# Processing Record 524299 | Murmashi
# Processing Record 5557293 | Sitka
# Processing Record 610298 | Beyneu
# Processing Record 3832899 | Viedma
# City not found. Skipping...
# Processing Record 2514301 | Mahon
# Processing Record 3724696 | Gonaïves
# Processing Record 6111696 | Port-Cartier
# Processing Record 2159220 | Mackay
# Processing Record 3838859 | Río Gallegos
# Processing Record 2145554 | Ulladulla
# Processing Record 5866583 | Saint Paul Harbor
# City not found. Skipping...
# Processing Record 585388 | Nardaran
# Processing Record 1264138 | Malaut
# Processing Record 2017155 | Saskylakh
# Processing Record 553514 | Kamennomostskiy
# City not found. Skipping...
# Processing Record 3466980 | Caravelas
# Processing Record 3448906 | São João Batista
# Processing Record 3869716 | Tocopilla
# Processing Record 544084 | Koslan
# Processing Record 965528 | Phalaborwa
# Processing Record 5880054 | Barrow
# Processing Record 3939168 | Huarmey
# City not found. Skipping...
# Processing Record 2178753 | Kirakira
# Processing Record 3403251 | Canto do Buriti
# Processing Record 4641998 | Millington
# Processing Record 2191562 | Dunedin
# Processing Record 3489440 | Morant Bay
# Processing Record 1259385 | Port Blair
# Processing Record 2647356 | Hastings
# Processing Record 576147 | Blagodatnoye
# Processing Record 1244926 | Hambantota
# Processing Record 2961459 | Skibbereen
# Processing Record 4032369 | Pangai
# Processing Record 1792916 | Tianpeng
# Processing Record 1529484 | Kumul
# Processing Record 2071860 | Esperance
# Processing Record 1805733 | Jinchang
# Processing Record 2065594 | Mount Isa
# Processing Record 1279945 | Jiuquan
# Processing Record 3516171 | Barra de Tecoanapa
# Processing Record 1043893 | Lichinga
# Processing Record 1610538 | Kabin Buri
# Processing Record 5942547 | Drayton Valley
# Processing Record 6050194 | La Sarre
# Processing Record 1067565 | Beloha
# Processing Record 1855540 | Naze
# Processing Record 4231997 | Avera
# Processing Record 779554 | Honningsvåg
# Processing Record 3608828 | Iralaya
# Processing Record 2715573 | Falkenberg
# City not found. Skipping...
# Processing Record 1526038 | Atbasar
# Processing Record 1217662 | Romitan
# Processing Record 3692073 | Santiago de Cao
# Processing Record 2141305 | Fayaoué
# Processing Record 72181 | Marzuq
# Processing Record 526543 | Miloslavskoye
# Processing Record 934649 | Cap Malheureux
# Processing Record 780687 | Berlevåg
# Processing Record 698102 | Ozerne
# Processing Record 2125693 | Evensk
# Processing Record 187896 | Mandera
# Processing Record 3848950 | La Rioja
# Processing Record 3996893 | Caborca
# City not found. Skipping...
# Processing Record 3394023 | Natal
# Processing Record 1636806 | Majene
# City not found. Skipping...
# Processing Record 2090021 | Namatanai
# Processing Record 3388456 | São José da Coroa Grande
# Processing Record 2173911 | Broken Hill
# Processing Record 286245 | Sur
# Processing Record 2138555 | Poum
# Processing Record 6453316 | Tromsø
# Processing Record 1497210 | Novoagansk
# Processing Record 500695 | Rudnichnyy
# Processing Record 2206874 | Waipawa
# Processing Record 2173125 | Burnie
# Processing Record 3893629 | Coquimbo
# Processing Record 1529195 | Shihezi
# Processing Record 2457161 | Gao
# Processing Record 2541479 | Nador
# Processing Record 2510253 | Torrevieja
# Processing Record 6457397 | Bose
# Processing Record 1693303 | Pitogo
# Processing Record 5808079 | Redmond
# Processing Record 5703673 | Elko
# Processing Record 3403687 | Camocim
# Processing Record 3418910 | Upernavik
# Processing Record 1512019 | Aksarka
# Processing Record 1214488 | Meulaboh
# Processing Record 876177 | Luau
# Processing Record 7647007 | Bariloche
# Processing Record 2038541 | Baiquan
# Processing Record 1485904 | Yermakovskoye
# Processing Record 2012530 | Zhigansk
# City not found. Skipping...
# Processing Record 778707 | Mehamn
# Processing Record 1267390 | Kavaratti
# Processing Record 5870133 | Nome
# Processing Record 515879 | Oktyabr'skiy
# Processing Record 1273403 | Datia
# Processing Record 3448903 | São João da Barra
# Processing Record 3465080 | Cruzeiro do Sul
# Processing Record 1254709 | Tezu
# Processing Record 2630299 | Hofn
# Processing Record 1633070 | Palembang
# Processing Record 3628503 | San Carlos
# Processing Record 1090225 | Koungou
# City not found. Skipping...
# Processing Record 2013392 | Vilyuysk
# Processing Record 2446267 | Dakoro
# Processing Record 5563397 | Eureka
# Processing Record 2059470 | Victor Harbor
# Processing Record 5380437 | Pacific Grove
# Processing Record 1714733 | Dingle
# Processing Record 1152432 | Lang Suan
# Processing Record 3414079 | Olafsvik
# Processing Record 697957 | Partyzany
# Processing Record 1849831 | Toyooka
# Processing Record 5554072 | Juneau
# Processing Record 986717 | Kruisfontein
# Processing Record 3458498 | Linhares
# Processing Record 3152995 | Hemnesberget
# Processing Record 3380290 | Sinnamary
# Processing Record 2953402 | Bad Mergentheim
# Processing Record 2068110 | Kununurra
# Processing Record 2027316 | Ayan
# Processing Record 3074102 | Jistebnice
# Processing Record 1855342 | Nishihara
# Processing Record 3893726 | Constitución
# Processing Record 3031008 | Arrondissement de Bourg-en-Bresse
# Processing Record 3359638 | Walvis Bay
# Processing Record 4462716 | Cumberland
# Processing Record 2374583 | Bubaque
# Processing Record 3583155 | Sesori
# Processing Record 3572462 | Dunmore Town
# Processing Record 1496130 | Onguday
# Processing Record 141736 | Bam
# Processing Record 2417988 | Macenta
# Processing Record 6144312 | Sept-Îles
# Processing Record 2619767 | Skjold
# Processing Record 2184707 | Wanaka
# Processing Record 3827407 | Venustiano Carranza
# Processing Record 6167817 | Torbay
# Processing Record 6137462 | Saint-Augustin
# Processing Record 2998285 | Arrondissement de Limoges
# Processing Record 3698304 | Chimbote
# Processing Record 6144195 | Senneterre
# Processing Record 3868707 | Valdivia
# Processing Record 1785655 | Yunyang
# Processing Record 1668355 | Tainan City
# Processing Record 2156643 | Mount Gambier
# Processing Record 469341 | Yam
# Processing Record 463355 | Zheleznodorozhnyy
# Processing Record 2447416 | Ayorou
# Processing Record 575480 | Bogovarovo
# Processing Record 5044290 | Saint Anthony
# Processing Record 935214 | Saint-Pierre
# Processing Record 1497337 | Kayerkan
# Processing Record 2172797 | Cairns
# Processing Record 1026014 | Tete
# Processing Record 3572189 | High Rock
# Processing Record 3659711 | Cariamanga
# Processing Record 3840092 | Puerto Madryn
# Processing Record 2460954 | Araouane
# Processing Record 5780557 | Riverton
# Processing Record 1651810 | Airai
# Processing Record 898947 | Senanga
# Processing Record 330120 | NEDJO
# Processing Record 614897 | Diok’nisi
# Processing Record 2294034 | Winneba
# Processing Record 3195214 | Metlika
# Processing Record 2025159 | Dalnerechensk
# City not found. Skipping...
# Processing Record 2338660 | Yaan
# Processing Record 3461592 | Ibipeba
# City not found. Skipping...
# Processing Record 665790 | Sulina
# Processing Record 3354071 | Oranjemund
# Processing Record 2269142 | Colares
# Processing Record 512576 | Parfen'yevo
# Processing Record 4805404 | Fairmont
# Processing Record 1174872 | Karachi
# Processing Record 3351663 | Benguela
# Processing Record 516647 | Nyandoma
# Processing Record 2399001 | Mayumba
# Processing Record 57000 | Hobyo
# Processing Record 3671450 | Inírida
# City not found. Skipping...
# Processing Record 4163971 | Melbourne
# Processing Record 3985168 | San Patricio
# Processing Record 2120048 | Ust-Nera
# Processing Record 3600931 | Tela
# Processing Record 1337619 | Ugoofaaru
# Processing Record 6050066 | La Ronge
# Processing Record 2212775 | Sabha
# Processing Record 2186111 | Ngunguru
# Processing Record 1847947 | Shingū
# City not found. Skipping...
# Processing Record 2510573 | Teguise
# City not found. Skipping...
# Processing Record 2016307 | Solnechnyy
# Processing Record 649630 | Kirkkonummi
# Processing Record 1786657 | Yinchuan
# Processing Record 569615 | Chekalin
# Processing Record 1495538 | Partizanskoye
# Processing Record 2702979 | Jönköping
# Processing Record 1526041 | Atasū
# Processing Record 4513583 | Hamilton
# Processing Record 2335953 | Jos
# Processing Record 4944903 | Nantucket
# Processing Record 2396853 | Omboué
# City not found. Skipping...
# Processing Record 2027296 | Aykhal
# Processing Record 1485020 | Znamenskoye
# Processing Record 6166142 | Thunder Bay
# Processing Record 3946820 | Barranca
# Processing Record 1728675 | Balabac
# Processing Record 6154383 | Spruce Grove
# City not found. Skipping...
# Processing Record 1854018 | Onoda
# Processing Record 2020738 | Litovko
# Processing Record 1254046 | Tura
# Processing Record 497971 | Sedkyrkeshch
# Processing Record 902620 | Mwinilunga
# Processing Record 6063191 | Mackenzie
# Processing Record 5062292 | Valley City
# Processing Record 3452483 | Prado
# Processing Record 1817968 | Anshun
# Processing Record 292672 | Sharjah city
# Processing Record 2332453 | Lagos
# Processing Record 4676798 | Brownwood
# Processing Record 1850523 | Tateyama
# Processing Record 359792 | Aswān
# Processing Record 4720067 | Lavaca
# Processing Record 2084442 | Vanimo
# Processing Record 2171099 | Codrington
# Processing Record 4031742 | Egvekinot
# Processing Record 1650434 | Bambanglipuro
# Processing Record 5113760 | Corning
# Processing Record 660073 | Eurajoki
# Processing Record 553248 | Kamyzyak
# Processing Record 5097801 | Fairview
# Processing Record 779683 | Hammerfest
# Processing Record 5386754 | Redlands
# Processing Record 2024626 | Dzhebariki-Khaya
# Processing Record 1525798 | Balkhash
# Processing Record 1169580 | Nabisar
# Processing Record 2157373 | Mittagong
# Processing Record 2317765 | Zaria
# Processing Record 113632 | Taft
# City not found. Skipping...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data_df = pd.DataFrame({
    "City":city_name,
    "Lat":latitude,
    "Lon":longitude,
    "Max Temp":max_temp,
    "Humidity":humidity,
    "Cloudiness":cloudiness,
    "Wind Speed":wind_speed,
    "Country":country,
    "Date":weather_date     
})

weather_data_df.count()
# Out:
# City          569
# Lat           569
# Lon           569
# Max Temp      569
# Humidity      569
# Cloudiness    569
# Wind Speed    569
# Country       569
# Date          569
# dtype: int64

# %%
weather_data_df.head()
# Out:
#          City    Lat     Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Isangel -19.55  169.27     68.00       100          20       11.41
# 1  Nikolskoye  59.70   30.79     62.60        67          75        2.24
# 2     Ahipara -35.17  173.17     55.31        88          10        7.23
# 3   Hong Kong  22.29  114.16     84.00        79          17        4.00
# 4   Ostrovnoy  68.05   39.51     49.06        90         100        9.46
#
#   Country        Date
# 0      VU  1594579333
# 1      RU  1594579288
# 2      NZ  1594579334
# 3      HK  1594579415
# 4      RU  1594579427

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_data_df.describe()
# Out:
#               Lat         Lon    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  569.000000  569.000000  569.000000  569.000000  569.000000  569.000000
# mean    20.496977   19.997047   68.914341   68.843585   49.339192    8.245009
# std     34.484657   88.788054   14.776832   20.572231   40.310318    5.403172
# min    -54.800000 -179.170000   32.760000    3.000000    0.000000    0.510000
# 25%     -8.930000  -55.150000   57.000000   57.000000    2.000000    4.210000
# 50%     26.540000   24.440000   70.270000   74.000000   40.000000    6.930000
# 75%     49.820000   94.390000   80.460000   85.000000   93.000000   11.410000
# max     78.220000  179.320000  104.000000  100.000000  100.000000   33.040000
#
#                Date
# count  5.690000e+02
# mean   1.594580e+09
# std    9.086254e+01
# min    1.594579e+09
# 25%    1.594580e+09
# 50%    1.594580e+09
# 75%    1.594580e+09
# max    1.594580e+09

# %%
# Make a new DataFrame to drop any cities with a humidity greather than 100
lower_humidity_df = weather_data_df.loc[weather_data_df["Humidity"] <= 100, :]

lower_humidity_df.to_csv("output_data/WeatherData.csv", index=False, header=True)

lower_humidity_df.head()
# Out:
#          City    Lat     Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Isangel -19.55  169.27     68.00       100          20       11.41
# 1  Nikolskoye  59.70   30.79     62.60        67          75        2.24
# 2     Ahipara -35.17  173.17     55.31        88          10        7.23
# 3   Hong Kong  22.29  114.16     84.00        79          17        4.00
# 4   Ostrovnoy  68.05   39.51     49.06        90         100        9.46
#
#   Country        Date
# 0      VU  1594579333
# 1      RU  1594579288
# 2      NZ  1594579334
# 3      HK  1594579415
# 4      RU  1594579427

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
today_date = pd.to_datetime('today').strftime("%m/%d/%Y")

plt.scatter(lower_humidity_df["Lat"],lower_humidity_df["Max Temp"], edgecolor = 'black')
plt.grid(color="black", linewidth=1,alpha=0.20)
plt.title("City Latitude vs Max Temperature (" + today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.savefig("output_data/LatitudeVSMaxTemperature.png")
plt.show()

# %% [markdown]
# #### The graph is showing the correlation between latitude and maximum tempature. The closer to the equator (0 Latitude), the hotter the temperatures.

# %%
plt.scatter(lower_humidity_df["Lat"],lower_humidity_df["Humidity"], edgecolor = 'black')
plt.grid(color="black", linewidth=1,alpha=0.20)
plt.title("City Latitude vs Humidity (" + today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.savefig("output_data/LatitudeVSHumidity.png")
plt.show()

# %% [markdown]
# #### The graph is showing the correlation between latitude and humidity. There does not appear to be a correlation between latitude and humidity.

# %%
plt.scatter(lower_humidity_df["Lat"],lower_humidity_df["Cloudiness"], edgecolor = 'black')
plt.grid(color="black", linewidth=1,alpha=0.20)
plt.title("City Latitude vs Cloudiness (" + today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.savefig("output_data/LatitudeVSCloudiness.png")
plt.show()

# %% [markdown]
# #### The graph is showing the correlation between latitude and cloudiness. There does not appear to be a correlation between latitude and cloudiness.

# %%
plt.scatter(lower_humidity_df["Lat"],lower_humidity_df["Wind Speed"], edgecolor = 'black')
plt.grid(color="black", linewidth=1,alpha=0.20)
plt.title("City Latitude vs Wind Speed (" + today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig("output_data/LatitudeVSWindSpeed.png")
plt.show()

# %% [markdown]
# #### The graph is showing the correlation between latitude and wind speed. It appears no matter what latitude the wind speeds are lower with a few outliers.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def hemp_regression(x_values,y_values,y_axis_name,hemisphere):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(x_values.min(), y_values.min()),fontsize=15,color="red")
    plt.title(hemisphere + " - " + y_axis_name + " vs. Latitude Linear Regression")
    plt.xlabel("Latitude")
    plt.ylabel(y_axis_name)
    print(f"The r-squared is: {rvalue**2}")
    plt.savefig("output_data/Regression_"+ hemisphere + "_LatitudeVs" + y_axis_name + ".png")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere_df = lower_humidity_df.loc[lower_humidity_df["Lat"] >= 0, :]
northern_hemisphere_df.head()
# Out:
#          City    Lat     Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 1  Nikolskoye  59.70   30.79     62.60        67          75        2.24
# 3   Hong Kong  22.29  114.16     84.00        79          17        4.00
# 4   Ostrovnoy  68.05   39.51     49.06        90         100        9.46
# 5  Chokurdakh  70.63  147.92     56.88        61          85        9.46
# 6    Klaksvík  62.23   -6.59     51.80        93         100       12.75
#
#   Country        Date
# 1      RU  1594579288
# 3      HK  1594579415
# 4      RU  1594579427
# 5      RU  1594579289
# 6      FO  1594579335

# %%
# Create Northern and Southern Hemisphere DataFrames
southern_hemisphere_df = lower_humidity_df.loc[lower_humidity_df["Lat"] < 0, :]
southern_hemisphere_df.head()
# Out:
#          City    Lat     Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Isangel -19.55  169.27     68.00       100          20       11.41
# 2     Ahipara -35.17  173.17     55.31        88          10        7.23
# 7   Busselton -33.65  115.33     55.00        81           2       12.93
# 9      Atuona  -9.80 -139.03     80.44        74           0       23.67
# 12     Padang  -0.95  100.35     77.65        80          75        5.32
#
#    Country        Date
# 0       VU  1594579333
# 2       NZ  1594579334
# 7       AU  1594579338
# 9       PF  1594579514
# 12      ID  1594579334

# %%
hemp_regression(northern_hemisphere_df["Lat"],northern_hemisphere_df["Max Temp"],"Max Temp","Northern Hemisphere")
# Out:
# The r-squared is: 0.5556132220679343

# %%
hemp_regression(southern_hemisphere_df["Lat"],southern_hemisphere_df["Max Temp"],"Max Temp","Southern Hemisphere")
# Out:
# The r-squared is: 0.7025437138326162

# %% [markdown]
# #### In both hemispheres, there appears to be a direct correlation between latitude and temperature. As the latitude increases the temperature decreases and as the latitude decreases the temperature increases.

# %%
hemp_regression(northern_hemisphere_df["Lat"],northern_hemisphere_df["Humidity"],"Humidity","Northern Hemisphere")
# Out:
# The r-squared is: 0.010835907801518718

# %%
hemp_regression(southern_hemisphere_df["Lat"],southern_hemisphere_df["Humidity"],"Humidity","Southern Hemisphere")
# Out:
# The r-squared is: 0.0007790658552899424

# %% [markdown]
# #### There appears to be no correlation between latitude and humidity. The regression lines are pretty straight showing there is no way of determing humidity based on latitude and vice versa.

# %%
hemp_regression(northern_hemisphere_df["Lat"],northern_hemisphere_df["Cloudiness"],"Cloudiness","Northern Hemisphere")
# Out:
# The r-squared is: 0.0001717601719599467

# %%
hemp_regression(southern_hemisphere_df["Lat"],southern_hemisphere_df["Cloudiness"],"Cloudiness","Southern Hemisphere")
# Out:
# The r-squared is: 0.04351876350410034

# %% [markdown]
# #### In the northern hemisphere, the regression line is almost flat which shows there is not much of a correlation between latitude and cloudiness. In the southern hemisphere, the line has a slight upward trend which denotes that as latitude decreases the cloudiness increases.

# %%
hemp_regression(northern_hemisphere_df["Lat"],northern_hemisphere_df["Wind Speed"],"Wind Speed","Northern Hemisphere")
# Out:
# The r-squared is: 0.019934783125585196

# %%
hemp_regression(southern_hemisphere_df["Lat"],southern_hemisphere_df["Wind Speed"],"Wind Speed","Southern Hemisphere")
# Out:
# The r-squared is: 0.00939739808743175

# %% [markdown]
# #### In both hemispheres, the regression lines have a slight downward trend which denotes that as latitude decreases the wind speed decreases as well.
