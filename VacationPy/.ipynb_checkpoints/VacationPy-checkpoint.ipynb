# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

from pprint import pprint

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weather_file = "..\WeatherPy\output_data\WeatherData.csv"
weather_data_df = pd.read_csv(weather_file)

weather_data_df.head()
# Out:
#             City    Lat     Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Cockburn Town  21.46  -71.14     84.20        70          40       11.41
# 1       Meulaboh   4.14   96.13     76.42        78         100        2.08
# 2     Bredasdorp -34.53   20.04     62.60        48           0       19.46
# 3        Mataura -46.19  168.86     42.94        86          86        3.98
# 4         Clovis  36.83 -119.70    109.99        12          20        6.93
#
#   Country        Date
# 0      TC  1594600155
# 1      ID  1594600155
# 2      ZA  1594600085
# 3      NZ  1594600044
# 4      US  1594599986

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps
gmaps.configure(api_key=g_key)

# Change humidity to a float
weather_data_df["Humidity"] = weather_data_df["Humidity"].astype(float)

# Use the Lat and Long as locations and Humidity as the weight
locations = weather_data_df[["Lat", "Lon"]]
weights = weather_data_df["Humidity"]

# Add heamtmap layer to map
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights, dissipating=False,
                                 max_intensity=weights.max(), point_radius=3)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# Narrow down the cities to fit weather conditions
weather_data_filtered_df = weather_data_df.loc[(weather_data_df["Max Temp"] > 70) &
                                               (weather_data_df["Max Temp"] < 80) &
                                               (weather_data_df["Wind Speed"] < 10) &
                                               (weather_data_df["Cloudiness"] == 0)]

# Drop any rows with null values
weather_data_filtered_df = weather_data_filtered_df.dropna(how="any")
weather_data_filtered_df
# Out:
#               City    Lat    Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 14           Adeje  28.12 -16.73     75.00      78.0           0        8.05
# 55         Tripoli  32.88  13.19     75.34      73.0           0        6.08
# 202    Mitsamiouli -11.38  43.28     77.22      71.0           0        4.05
# 247       Agropoli  40.35  15.00     75.00      62.0           0        5.99
# 307           Lata  40.16  -8.33     72.00      73.0           0        2.37
# 310          Sirte  31.21  16.59     75.45      83.0           0        9.31
# 395  Pimenta Bueno -11.67 -61.19     76.15      59.0           0        2.28
# 408          Cabra  37.47  -4.44     77.00      63.0           0        5.06
# 410   Lora del Río  37.66  -5.53     78.01      73.0           0        5.82
# 428      Calatayud  41.35  -1.64     71.60      94.0           0        3.36
# 472       Cabedelo  -6.98 -34.83     73.40      88.0           0        4.70
# 529      Riberalta -10.98 -66.10     76.78      71.0           0        2.68
# 546     Djebeniana  35.03  10.91     77.00      73.0           0        4.54
#
#     Country        Date
# 14       ES  1594600156
# 55       LY  1594600162
# 202      KM  1594600182
# 247      IT  1594600187
# 307      PT  1594600067
# 310      LY  1594600195
# 395      BR  1594600209
# 408      ES  1594600101
# 410      ES  1594600211
# 428      ES  1594600214
# 472      BR  1594600221
# 529      BO  1594600229
# 546      TN  1594600232

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# Store into variable named hotel_df
hotel_df = weather_data_filtered_df

# Add a "Hotel Name" column to the DataFrame
hotel_df["Hotel Name"] = ""

hotel_name = []
hotel_lat = []
hotel_long = []
origin_city = []

# Set parameters to search for hotels within 5000 meters
target_search = "lodging"

for index, row in hotel_df.iterrows():
    lat = row["Lat"]
    long = row["Lon"]
    city = row["City"]
    
    parameters = {
        "location" : f"{lat},{long}",
        "types" : target_search,
        "rankby" : "distance",
        "locationbias" : "5000",
        "key" : g_key
    }
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    hotel_response = requests.get(base_url, parameters).json()
    
    origin_city.append(city)
    hotel_name.append(hotel_response["results"][0]["name"])
    hotel_lat.append(hotel_response["results"][0]["geometry"]["location"]["lat"])
    hotel_long.append(hotel_response["results"][0]["geometry"]["location"]["lng"])

# %%
hotel_info_df = pd.DataFrame({
    "City" : origin_city,
    "Hotel Name" : hotel_name,
    "Hotel Latitude" : hotel_lat,
    "Hotel Longitue" : hotel_long
})

hotel_city = []
hotel_country = []

location_type = "ROOFTOP"
result_type = "street_address"

for index, row in hotel_info_df.iterrows():
    lat = row["Hotel Latitude"]
    long = row["Hotel Longitue"]
    
    url = "https://maps.googleapis.com/maps/api/geocode/json?latlng="
    city_url = (f"{url}{lat},{long}&location_type=ROOFTOP&result_type=street_address&key={g_key}")
    
    city_response = requests.get(city_url).json()  
    #hotel_city.append(city_response["results"][0]["address_components"][3]["long_name"])
    #hotel_city.append(city_response["results"][0]["address_components"][2]["long_name"])
    pprint(city_response["results"])
# Out:
# [{'address_components': [{'long_name': '7',
#                           'short_name': '7',
#                           'types': ['street_number']},
#                          {'long_name': 'Calle 30 de Mayo',
#                           'short_name': 'Calle 30 de Mayo',
#                           'types': ['route']},
#                          {'long_name': 'Adeje',
#                           'short_name': 'Adeje',
#                           'types': ['locality', 'political']},
#                          {'long_name': 'Santa Cruz de Tenerife',
#                           'short_name': 'TF',
#                           'types': ['administrative_area_level_2',
#                                     'political']},
#                          {'long_name': 'Canarias',
#                           'short_name': 'CN',
#                           'types': ['administrative_area_level_1',
#                                     'political']},
#                          {'long_name': 'Spain',
#                           'short_name': 'ES',
#                           'types': ['country', 'political']},
#                          {'long_name': '38670',
#                           'short_name': '38670',
#                           'types': ['postal_code']}],
#   'formatted_address': 'Calle 30 de Mayo, 7, 38670 Adeje, Santa Cruz de '
#                        'Tenerife, Spain',
#   'geometry': {'location': {'lat': 28.1202388, 'lng': -16.7295962},
#                'location_type': 'ROOFTOP',
#                'viewport': {'northeast': {'lat': 28.1215877802915,
#                                           'lng': -16.7282472197085},
#                             'southwest': {'lat': 28.1188898197085,
#                                           'lng': -16.7309451802915}}},
#   'place_id': 'ChIJjZuIqpiQagwR4cKsahBF-lg',
#   'plus_code': {'compound_code': '47CC+35 Adeje, Spain',
#                 'global_code': '7CW547CC+35'},
#   'types': ['street_address']}]
# []
# []
# [{'address_components': [{'long_name': '72',
#                           'short_name': '72',
#                           'types': ['street_number']},
#                          {'long_name': 'Via Alcide de Gasperi',
#                           'short_name': 'Via Alcide de Gasperi',
#                           'types': ['route']},
#                          {'long_name': 'Agropoli',
#                           'short_name': 'Agropoli',
#                           'types': ['locality', 'political']},
#                          {'long_name': 'Agropoli',
#                           'short_name': 'Agropoli',
#                           'types': ['administrative_area_level_3',
#                                     'political']},
#                          {'long_name': 'Provincia di Salerno',
#                           'short_name': 'SA',
#                           'types': ['administrative_area_level_2',
#                                     'political']},
#                          {'long_name': 'Campania',
#                           'short_name': 'Campania',
#                           'types': ['administrative_area_level_1',
#                                     'political']},
#                          {'long_name': 'Italy',
#                           'short_name': 'IT',
#                           'types': ['country', 'political']},
#                          {'long_name': '84043',
#                           'short_name': '84043',
#                           'types': ['postal_code']}],
#   'formatted_address': 'Via Alcide de Gasperi, 72, 84043 Agropoli SA, Italy',
#   'geometry': {'location': {'lat': 40.3508897, 'lng': 14.9999417},
#                'location_type': 'ROOFTOP',
#                'viewport': {'northeast': {'lat': 40.3522386802915,
#                                           'lng': 15.0012906802915},
#                             'southwest': {'lat': 40.3495407197085,
#                                           'lng': 14.9985927197085}}},
#   'place_id': 'ChIJH2ywIVv-OxMRcDFnoPJC4hc',
#   'plus_code': {'compound_code': '9X2X+9X Agropoli, SA, Italy',
#                 'global_code': '8FGP9X2X+9X'},
#   'types': ['street_address']}]
# []
# []
# [{'address_components': [{'long_name': '211',
#                           'short_name': '211',
#                           'types': ['street_number']},
#                          {'long_name': 'Rua Floriano Peixoto',
#                           'short_name': 'R. Floriano Peixoto',
#                           'types': ['route']},
#                          {'long_name': 'Pioneiros',
#                           'short_name': 'Pioneiros',
#                           'types': ['political',
#                                     'sublocality',
#                                     'sublocality_level_1']},
#                          {'long_name': 'Pimenta Bueno',
#                           'short_name': 'Pimenta Bueno',
#                           'types': ['administrative_area_level_2',
#                                     'political']},
#                          {'long_name': 'Rondônia',
#                           'short_name': 'RO',
#                           'types': ['administrative_area_level_1',
#                                     'political']},
#                          {'long_name': 'Brazil',
#                           'short_name': 'BR',
#                           'types': ['country', 'political']},
#                          {'long_name': '78984-000',
#                           'short_name': '78984-000',
#                           'types': ['postal_code']}],
#   'formatted_address': 'R. Floriano Peixoto, 211 - Pioneiros, Pimenta Bueno - '
#                        'RO, 78984-000, Brazil',
#   'geometry': {'location': {'lat': -11.6702047, 'lng': -61.18898129999999},
#                'location_type': 'ROOFTOP',
#                'viewport': {'northeast': {'lat': -11.6688557197085,
#                                           'lng': -61.18763231970849},
#                             'southwest': {'lat': -11.6715536802915,
#                                           'lng': -61.1903302802915}}},
#   'place_id': 'ChIJAQDwWoDmt5MR8YUGVneQHrA',
#   'plus_code': {'compound_code': '8RH6+WC Pioneiros, Pimenta Bueno - State of '
#                                  'Rondônia, Brazil',
#                 'global_code': '57WW8RH6+WC'},
#   'types': ['street_address']}]
# [{'address_components': [{'long_name': '25',
#                           'short_name': '25',
#                           'types': ['street_number']},
#                          {'long_name': 'Calle Antonio Povedano',
#                           'short_name': 'Calle Antonio Povedano',
#                           'types': ['route']},
#                          {'long_name': 'Cabra',
#                           'short_name': 'Cabra',
#                           'types': ['locality', 'political']},
#                          {'long_name': 'Córdoba',
#                           'short_name': 'Córdoba',
#                           'types': ['administrative_area_level_2',
#                                     'political']},
#                          {'long_name': 'Andalucía',
#                           'short_name': 'AL',
#                           'types': ['administrative_area_level_1',
#                                     'political']},
#                          {'long_name': 'Spain',
#                           'short_name': 'ES',
#                           'types': ['country', 'political']},
#                          {'long_name': '14940',
#                           'short_name': '14940',
#                           'types': ['postal_code']}],
#   'formatted_address': 'Calle Antonio Povedano, 25, 14940 Cabra, Córdoba, '
#                        'Spain',
#   'geometry': {'location': {'lat': 37.47031, 'lng': -4.4398799},
#                'location_type': 'ROOFTOP',
#                'viewport': {'northeast': {'lat': 37.47165898029149,
#                                           'lng': -4.438530919708498},
#                             'southwest': {'lat': 37.46896101970849,
#                                           'lng': -4.441228880291503}}},
#   'place_id': 'ChIJf9-EoCp0bQ0R6S6AXy9PkYE',
#   'plus_code': {'compound_code': 'FHC6+42 Cabra, Spain',
#                 'global_code': '8C9QFHC6+42'},
#   'types': ['street_address']}]
# [{'address_components': [{'long_name': '10',
#                           'short_name': '10',
#                           'types': ['street_number']},
#                          {'long_name': 'Plaza Axati',
#                           'short_name': 'Plaza Axati',
#                           'types': ['route']},
#                          {'long_name': 'Lora del Río',
#                           'short_name': 'Lora del Río',
#                           'types': ['locality', 'political']},
#                          {'long_name': 'Sevilla',
#                           'short_name': 'Sevilla',
#                           'types': ['administrative_area_level_2',
#                                     'political']},
#                          {'long_name': 'Andalucía',
#                           'short_name': 'AL',
#                           'types': ['administrative_area_level_1',
#                                     'political']},
#                          {'long_name': 'Spain',
#                           'short_name': 'ES',
#                           'types': ['country', 'political']},
#                          {'long_name': '41440',
#                           'short_name': '41440',
#                           'types': ['postal_code']}],
#   'formatted_address': 'Plaza Axati, 10, 41440 Lora del Río, Sevilla, Spain',
#   'geometry': {'location': {'lat': 37.65964719999999,
#                             'lng': -5.526038900000001},
#                'location_type': 'ROOFTOP',
#                'viewport': {'northeast': {'lat': 37.6609961802915,
#                                           'lng': -5.524689919708499},
#                             'southwest': {'lat': 37.6582982197085,
#                                           'lng': -5.527387880291503}}},
#   'place_id': 'ChIJQ85cv5jvEg0R2vPUPLDsLcI',
#   'plus_code': {'compound_code': 'MF5F+VH Lora del Río, Spain',
#                 'global_code': '8C9PMF5F+VH'},
#   'types': ['street_address']}]
# [{'address_components': [{'long_name': '3',
#                           'short_name': '3',
#                           'types': ['street_number']},
#                          {'long_name': 'Paseo Cortes de Aragón',
#                           'short_name': 'Paseo Cortes de Aragón',
#                           'types': ['route']},
#                          {'long_name': 'Calatayud',
#                           'short_name': 'Calatayud',
#                           'types': ['locality', 'political']},
#                          {'long_name': 'Zaragoza',
#                           'short_name': 'Z',
#                           'types': ['administrative_area_level_2',
#                                     'political']},
#                          {'long_name': 'Aragón',
#                           'short_name': 'Aragón',
#                           'types': ['administrative_area_level_1',
#                                     'political']},
#                          {'long_name': 'Spain',
#                           'short_name': 'ES',
#                           'types': ['country', 'political']},
#                          {'long_name': '50300',
#                           'short_name': '50300',
#                           'types': ['postal_code']}],
#   'formatted_address': 'Paseo Cortes de Aragón, 3, 50300 Calatayud, Zaragoza, '
#                        'Spain',
#   'geometry': {'location': {'lat': 41.3515827, 'lng': -1.6422617},
#                'location_type': 'ROOFTOP',
#                'viewport': {'northeast': {'lat': 41.3529316802915,
#                                           'lng': -1.640912719708498},
#                             'southwest': {'lat': 41.35023371970851,
#                                           'lng': -1.643610680291502}}},
#   'place_id': 'ChIJyVlPgiyPWw0RzSk3W90Uua8',
#   'plus_code': {'compound_code': '9925+J3 Calatayud, Spain',
#                 'global_code': '8CHW9925+J3'},
#   'types': ['street_address']}]
# [{'address_components': [{'long_name': '468',
#                           'short_name': '468',
#                           'types': ['street_number']},
#                          {'long_name': 'Rua Estudante Paulo Maia Guimarães',
#                           'short_name': 'R. Est. Paulo Maia Guimarães',
#                           'types': ['route']},
#                          {'long_name': 'Praia Formosa',
#                           'short_name': 'Praia Formosa',
#                           'types': ['political',
#                                     'sublocality',
#                                     'sublocality_level_1']},
#                          {'long_name': 'Cabedelo',
#                           'short_name': 'Cabedelo',
#                           'types': ['administrative_area_level_2',
#                                     'political']},
#                          {'long_name': 'Paraíba',
#                           'short_name': 'PB',
#                           'types': ['administrative_area_level_1',
#                                     'political']},
#                          {'long_name': 'Brazil',
#                           'short_name': 'BR',
#                           'types': ['country', 'political']},
#                          {'long_name': '58101-160',
#                           'short_name': '58101-160',
#                           'types': ['postal_code']}],
#   'formatted_address': 'R. Est. Paulo Maia Guimarães, 468 - Praia Formosa, '
#                        'Cabedelo - PB, 58101-160, Brazil',
#   'geometry': {'location': {'lat': -6.980526999999999, 'lng': -34.829204},
#                'location_type': 'ROOFTOP',
#                'viewport': {'northeast': {'lat': -6.979178019708497,
#                                           'lng': -34.8278550197085},
#                             'southwest': {'lat': -6.981875980291502,
#                                           'lng': -34.83055298029149}}},
#   'place_id': 'ChIJs4r0AnggrQcRT5rBDnx0hvA',
#   'plus_code': {'compound_code': '259C+Q8 Vila Sao Joao, Cabedelo - State of '
#                                  'Paraíba, Brazil',
#                 'global_code': '6957259C+Q8'},
#   'types': ['street_address']}]
# []
# []

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map


# Display figure
